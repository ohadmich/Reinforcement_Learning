# %% [markdown]
# # Reinforcement Learning for Mountain Car game

# %% [markdown]
# Import libraries:

# %%
import numpy as np
import tensorflow as tf
import gym
import matplotlib.pyplot as plt
% matplotlib notebook
# Out:
# c:\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### Defining hyperparameters:

# %% [markdown]
# Here we define all the hyperparameters for the model, this will allow as to easily iterate and find the values that give best results.

# %%
num_episodes = 100      # Number of episodes for training
learning_rate = 0.01
gamma = 0.99           # Discount factor for reward
num_Hidden = 200       # number of nodes in the hidden layer

env = gym.make('MountainCar-v0')    # Choose a game and create an environment
env._max_episode_steps = 5000     # limits the number of steps in an episode
obs_dim = env.reset().shape      # obervation dimension
num_actions = env.action_space.n # number of actions (this works only for descrete action space, which is the case here)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %% [markdown]
# ### Define functions

# %% [markdown]
# **Discount reward function**: We we'll train our agent based on the reward gained for his actions. For each action we'll define the episode reward as the total reward gained in all the next steps of the current episode. Since a reward gained further away in the future has less correlation to the present action, we will give it less weight by discounting future rewards.
#
# The formula for the discounted rewards is given by:
#
# $$ R_t = \sum_k \gamma^k r_{t+k} $$
#
# Where $r_t$ is the reward gained in the step $t$ and $\gamma \in [0,1]$ is a hyperparameter called the discount factor.
# Here we define a function that takes a vector of rewards in consequent steps and returns the discounted reward vector:

# %%
def discount_rewards(r):
    '''Takes a 1D rewards (one episode) and discounts it and also standardize
    the rewards to be unit normal (helps control the gradient estimator variance)'''
    
    # Discounting
    dis_r = np.zeros_like(r)
    running_sum = 0
    for t in reversed(range(len(r))):
        running_sum = gamma*running_sum + r[t]
        dis_r[t] = running_sum
    
    # Normailzing
    dis_r = (dis_r - np.mean(dis_r))/np.std(dis_r)
        
    return dis_r

# %% [markdown]
# ### Build model

# %% [markdown]
# We start by creating the simplest model: Observation as an input, one hidden layer and two nodes in the output layer - corresponding to the action of moving right (1) or left (0).
#
# To keep order in our model, we use name scopes which basically group the layers of our model in a simple to follow way. Eventually, when using [TensorBoard](https://www.tensorflow.org/guide/summaries_and_tensorboard) for visualizing the model, the graph is more readable and makes it easy to understand the model and find errors.

# %%
'''Create placeholders for inputs'''
# A place holder for input observations
input_ = tf.placeholder(tf.float32, shape = (None, obs_dim[0]), name = "input")
# A place holder for actions in a full episode
actions = tf.placeholder(tf.float32, shape = (None, num_actions), name = "actions")
# A place holder for discounted rewards in a full episode
dis_rewards = tf.placeholder(tf.float32, shape = (None, ), name = "dis_rewards")

'''Fully connected layers'''
with tf.name_scope("FC1"):
    fc1 = tf.layers.dense(inputs = input_, units = num_Hidden ,activation = tf.nn.relu, name = "fc1" )

with tf.name_scope("FC2"):
    fc2 = tf.layers.dense(inputs = fc1, units = num_actions ,activation = None, name = "fc2" )

with tf.name_scope("Action_PDF"):
    # Operate with softmax on fc2 outputs to get an action probability distribution
    action_prob_dist = tf.nn.softmax(logits = fc2, name = "softamx")

with tf.name_scope("Loss"):
    '''Define loss'''
    # Fist define reular softmax cross entropy loss
    CE_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels = actions, logits = fc2, name = "CE_loss")
    # Modulate the loss based on our discounted reward - this is where reinforcment learning happens,
    # we favor actions that produced high reward
    loss = tf.reduce_mean(CE_loss * dis_rewards)

with tf.name_scope("Training"):
    '''Define optimizer'''
    training_opt = tf.train.AdamOptimizer(learning_rate).minimize(loss)

'''Define saver for saving and restoring model'''
saver = tf.train.Saver()

# %% [markdown]
# Define a writer for saving summaries to TensorBoard:

# %%
# writer = tf.summary.FileWriter("./tensorboard/1/")

# %% [markdown]
# Here is an example of a graph visualization:
#
# <img src="./img/model_graph.png" width="500">
#
# Each block in the graph is expandable and let you see the content inside, for example see an [image](./img/model_graph_loss.png) with expanded loss block.

# %% [markdown]
# ### Train model

# %% [markdown]
# Now that we have a model ready, we can start training it.
#
# Our goal is to achieve a model that uses the current observation to create the best probability distribution function (PDF) for the next action to be taken. This is **not a deterministic model** - the agent has a fine probability to take any action after receiving an observation, with larger probability to take favorable actions.
#
# To achieve that, in each step, we use our model to generate a PDF of actions, draw an action out of it and take the next step.
# When we reach the end of the episode, we compute the episode loss by feeding the observation, action and discounted rewards vectors (which we kept track of). Our optimizer minimizes the loss which makes favorable (unfavorable) actions more probable (less probable) due to the multiplicative factor of the discounted reward. By repeating these steps to each episode, our agent gradually improves its PDF and becomes a better player!

# %%
ep_action, ep_obs, ep_reward = [], [], []  # Allocate space for episode actions, observations and rewards
tot_ep_reward = [] # Total episode reward
mean_reward = []

''' Run TF session '''
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    ''' Run episodes '''
    for ep in range(num_episodes): 
        obs = env.reset()  # Reset and save first observation
        ep_obs.append(obs) # append observation

        ''' Run steps '''
        while True:
            # Propagate forward to compute action probability distribution
            apd = np.squeeze(sess.run(action_prob_dist, feed_dict = {input_ : obs.reshape((1,obs_dim[0]))}))
            action = np.random.choice(np.arange(num_actions), p = apd)   # Sample an action based on the pdf
            obs, reward, done, info = env.step(action)  # Take action and save observation, reward and done boolean
            
            # Convert action to one hot
            action_oh = np.zeros((1,num_actions))
            action_oh[0,action] = 1
            
            ep_action.append(action_oh)  # append action
            ep_obs.append(obs)           # append observation
            ep_reward.append(reward)     # append reward

            if done: 
                # Stack vertically episode parameters to one np.array
                ep_action = np.vstack(ep_action)
                ep_obs = np.vstack(ep_obs)
                ep_reward = np.hstack(ep_reward)

                # Discount rewards
                dis_rewards_arr = discount_rewards(ep_reward)
                # Compute loss and optimize
                sess.run([loss, training_opt],
                         feed_dict = {input_ : ep_obs[:-1], actions : ep_action, dis_rewards : dis_rewards_arr})
                
                tot_ep_reward.append(np.sum(ep_reward))  # Compute total reward for episode
                mean_reward.append(np.mean(tot_ep_reward))
                
                 # print info
                print("-------------------------------------------------")
                print("Episode {}".format(ep))
                print("Episode ended after {} steps".format(ep_action.shape[0]))
                print("Accumulated reward in this episode {}".format(tot_ep_reward[ep]))
                print("Mean reward so far {:0.2f}".format(np.mean(tot_ep_reward)))
                print("Maximal reward so far {}".format(np.max(tot_ep_reward)))
                
                ep_action, ep_obs, ep_reward = [], [], []  # Clear episode values for next episode
                      
                break
                
    saver.save(sess, "models/MountainCar/model.ckpt") # save model for later
#     writer.add_graph(sess.graph) # Save graph for displaying with TensorBoard
env.close()
# Out:
# -------------------------------------------------
# Episode 0
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -5000.00
# Maximal reward so far -5000.0
# -------------------------------------------------
# Episode 1
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -5000.00
# Maximal reward so far -5000.0
# -------------------------------------------------
# Episode 2
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -5000.00
# Maximal reward so far -5000.0
# -------------------------------------------------
# Episode 3
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -5000.00
# Maximal reward so far -5000.0
# -------------------------------------------------
# Episode 4
# Episode ended after 3684 steps
# Accumulated reward in this episode -3684.0
# Mean reward so far -4736.80
# Maximal reward so far -3684.0
# -------------------------------------------------
# Episode 5
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4780.67
# Maximal reward so far -3684.0
# -------------------------------------------------
# Episode 6
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4812.00
# Maximal reward so far -3684.0
# -------------------------------------------------
# Episode 7
# Episode ended after 2518 steps
# Accumulated reward in this episode -2518.0
# Mean reward so far -4525.25
# Maximal reward so far -2518.0
# -------------------------------------------------
# Episode 8
# Episode ended after 2679 steps
# Accumulated reward in this episode -2679.0
# Mean reward so far -4320.11
# Maximal reward so far -2518.0
# -------------------------------------------------
# Episode 9
# Episode ended after 4279 steps
# Accumulated reward in this episode -4279.0
# Mean reward so far -4316.00
# Maximal reward so far -2518.0
# -------------------------------------------------
# Episode 10
# Episode ended after 4470 steps
# Accumulated reward in this episode -4470.0
# Mean reward so far -4330.00
# Maximal reward so far -2518.0
# -------------------------------------------------
# Episode 11
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4385.83
# Maximal reward so far -2518.0
# -------------------------------------------------
# Episode 12
# Episode ended after 2819 steps
# Accumulated reward in this episode -2819.0
# Mean reward so far -4265.31
# Maximal reward so far -2518.0
# -------------------------------------------------
# Episode 13
# Episode ended after 2610 steps
# Accumulated reward in this episode -2610.0
# Mean reward so far -4147.07
# Maximal reward so far -2518.0
# -------------------------------------------------
# Episode 14
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4203.93
# Maximal reward so far -2518.0
# -------------------------------------------------
# Episode 15
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4253.69
# Maximal reward so far -2518.0
# -------------------------------------------------
# Episode 16
# Episode ended after 2272 steps
# Accumulated reward in this episode -2272.0
# Mean reward so far -4137.12
# Maximal reward so far -2272.0
# -------------------------------------------------
# Episode 17
# Episode ended after 1354 steps
# Accumulated reward in this episode -1354.0
# Mean reward so far -3982.50
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 18
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4036.05
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 19
# Episode ended after 3016 steps
# Accumulated reward in this episode -3016.0
# Mean reward so far -3985.05
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 20
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4033.38
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 21
# Episode ended after 3500 steps
# Accumulated reward in this episode -3500.0
# Mean reward so far -4009.14
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 22
# Episode ended after 3223 steps
# Accumulated reward in this episode -3223.0
# Mean reward so far -3974.96
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 23
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4017.67
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 24
# Episode ended after 1457 steps
# Accumulated reward in this episode -1457.0
# Mean reward so far -3915.24
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 25
# Episode ended after 2995 steps
# Accumulated reward in this episode -2995.0
# Mean reward so far -3879.85
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 26
# Episode ended after 3247 steps
# Accumulated reward in this episode -3247.0
# Mean reward so far -3856.41
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 27
# Episode ended after 3715 steps
# Accumulated reward in this episode -3715.0
# Mean reward so far -3851.36
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 28
# Episode ended after 3724 steps
# Accumulated reward in this episode -3724.0
# Mean reward so far -3846.97
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 29
# Episode ended after 3495 steps
# Accumulated reward in this episode -3495.0
# Mean reward so far -3835.23
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 30
# Episode ended after 1587 steps
# Accumulated reward in this episode -1587.0
# Mean reward so far -3762.71
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 31
# Episode ended after 3200 steps
# Accumulated reward in this episode -3200.0
# Mean reward so far -3745.12
# Maximal reward so far -1354.0
# -------------------------------------------------
# Episode 32
# Episode ended after 998 steps
# Accumulated reward in this episode -998.0
# Mean reward so far -3661.88
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 33
# Episode ended after 2455 steps
# Accumulated reward in this episode -2455.0
# Mean reward so far -3626.38
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 34
# Episode ended after 2344 steps
# Accumulated reward in this episode -2344.0
# Mean reward so far -3589.74
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 35
# Episode ended after 1871 steps
# Accumulated reward in this episode -1871.0
# Mean reward so far -3542.00
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 36
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3581.41
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 37
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3618.74
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 38
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3654.15
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 39
# Episode ended after 3162 steps
# Accumulated reward in this episode -3162.0
# Mean reward so far -3641.85
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 40
# Episode ended after 4040 steps
# Accumulated reward in this episode -4040.0
# Mean reward so far -3651.56
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 41
# Episode ended after 2156 steps
# Accumulated reward in this episode -2156.0
# Mean reward so far -3615.95
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 42
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3648.14
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 43
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3678.86
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 44
# Episode ended after 2278 steps
# Accumulated reward in this episode -2278.0
# Mean reward so far -3647.73
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 45
# Episode ended after 2850 steps
# Accumulated reward in this episode -2850.0
# Mean reward so far -3630.39
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 46
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3659.53
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 47
# Episode ended after 4760 steps
# Accumulated reward in this episode -4760.0
# Mean reward so far -3682.46
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 48
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3709.35
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 49
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3735.16
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 50
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3759.96
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 51
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3783.81
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 52
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3806.75
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 53
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3828.85
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 54
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3850.15
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 55
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3870.68
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 56
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3890.49
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 57
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3909.62
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 58
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3928.10
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 59
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3945.97
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 60
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3963.25
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 61
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3979.97
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 62
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -3996.16
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 63
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4011.84
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 64
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4027.05
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 65
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4041.79
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 66
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4056.09
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 67
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4069.97
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 68
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4083.45
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 69
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4096.54
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 70
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4109.27
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 71
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4121.64
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 72
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4133.67
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 73
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4145.38
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 74
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4156.77
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 75
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4167.87
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 76
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4178.68
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 77
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4189.21
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 78
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4199.47
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 79
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4209.48
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 80
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4219.23
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 81
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4228.76
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 82
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4238.05
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 83
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4247.12
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 84
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4255.98
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 85
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4264.63
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 86
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4273.08
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 87
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4281.34
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 88
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4289.42
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 89
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4297.31
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 90
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4305.03
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 91
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4312.59
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 92
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4319.98
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 93
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4327.21
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 94
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4334.29
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 95
# Episode ended after 3830 steps
# Accumulated reward in this episode -3830.0
# Mean reward so far -4329.04
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 96
# Episode ended after 4503 steps
# Accumulated reward in this episode -4503.0
# Mean reward so far -4330.84
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 97
# Episode ended after 2460 steps
# Accumulated reward in this episode -2460.0
# Mean reward so far -4311.74
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 98
# Episode ended after 5000 steps
# Accumulated reward in this episode -5000.0
# Mean reward so far -4318.70
# Maximal reward so far -998.0
# -------------------------------------------------
# Episode 99
# Episode ended after 2783 steps
# Accumulated reward in this episode -2783.0
# Mean reward so far -4303.34
# Maximal reward so far -998.0

# %% [markdown]
# ### Assess model performance

# %% [markdown]
# In order to get a sense of how good our model is, and to see if our agent improves in the training process, we can plot the mean rewards gained in one episode over the episode number. This value would grow as our agent becomes more skilled and gains more rewards in each episode.

# %%
plt.figure(figsize=(8,4))
plt.plot(mean_reward)
plt.xlabel("episode", fontsize=14)
plt.ylabel("mean reward", fontsize = 14)
plt.title("Mean episode rewards over episode number", fontsize = 16)
plt.grid()

# %% [markdown]
# ### Watch the agent play an episode

# %% [markdown]
# This is the fun part!
# Now we get to see how good our agent really is by watching it play an episode. I also record the episode using the Monitor wrapper and limit the number of steps for this episode to 500, because this skilled agent can play forever...

# %%
env = gym.make('MountainCar-v0')
env._max_episode_steps = 500
# env = gym.wrappers.Monitor(env, "recording")
with tf.Session() as sess:
    saver.restore(sess, "models/MountainCar/model.ckpt") # load model
    obs = env.reset() # Reset env and save observation
    t = 0
    while True:
        env.render() # Render game
        # Use our model to create a probability distribution of actions based on observation
        apd = np.squeeze(sess.run(action_prob_dist, feed_dict={input_ : obs.reshape((1,obs_dim[0]))}))
        # Choose an action out of the PDF and take action
        action = np.random.choice(np.arange(num_actions), p = apd)
        obs, reward, done, info = env.step(action)
        t = t+1
        if done:
            print("Game ended after {} steps".format(t+1))
            break
env.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# INFO:tensorflow:Restoring parameters from models/MountainCar/model.ckpt
