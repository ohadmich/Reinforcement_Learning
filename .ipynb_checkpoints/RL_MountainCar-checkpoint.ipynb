# %% [markdown]
# # Reinforcement Learning for Mountain Car game

# %% [markdown]
# Import libraries:

# %%
import numpy as np
import tensorflow as tf
import gym
import matplotlib.pyplot as plt
% matplotlib notebook
# Out:
# c:\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### Defining hyperparameters:

# %% [markdown]
# Here we define all the hyperparameters for the model, this will allow as to easily iterate and find the values that give best results.

# %%
num_episodes = 100      # Number of episodes for training
learning_rate = 0.01
gamma = 0.99           # Discount factor for reward
num_Hidden = 200       # number of nodes in the hidden layer

env = gym.make('MountainCar-v0')    # Choose a game and create an environment
env = env.unwrapped              # The wrapper limits the number of steps in an episode to 200, let's get rid of it
obs_dim = env.reset().shape      # obervation dimension
num_actions = env.action_space.n # number of actions (this works only for descrete action space, which is the case here)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %% [markdown]
# ### Define functions

# %% [markdown]
# **Discount reward function**: We we'll train our agent based on the reward gained for his actions. For each action we'll define the episode reward as the total reward gained in all the next steps of the current episode. Since a reward gained further away in the future has less correlation to the present action, we will give it less weight by discounting future rewards.
#
# The formula for the discounted rewards is given by:
#
# $$ R_t = \sum_k \gamma^k r_{t+k} $$
#
# Where $r_t$ is the reward gained in the step $t$ and $\gamma \in [0,1]$ is a hyperparameter called the discount factor.
# Here we define a function that takes a vector of rewards in consequent steps and returns the discounted reward vector:

# %%
def discount_rewards(r):
    '''Takes a 1D rewards (one episode) and discounts it and also standardize
    the rewards to be unit normal (helps control the gradient estimator variance)'''
    
    # Discounting
    dis_r = np.zeros_like(r)
    running_sum = 0
    for t in reversed(range(len(r))):
        running_sum = gamma*running_sum + r[t]
        dis_r[t] = running_sum
    
    # Normailzing
    dis_r = (dis_r - np.mean(dis_r))/np.std(dis_r)
        
    return dis_r

# %% [markdown]
# ### Build model

# %% [markdown]
# We start by creating the simplest model: Observation as an input, one hidden layer and two nodes in the output layer - corresponding to the action of moving right (1) or left (0).
#
# To keep order in our model, we use name scopes which basically group the layers of our model in a simple to follow way. Eventually, when using [TensorBoard](https://www.tensorflow.org/guide/summaries_and_tensorboard) for visualizing the model, the graph is more readable and makes it easy to understand the model and find errors.

# %%
'''Create placeholders for inputs'''
# A place holder for input observations
input_ = tf.placeholder(tf.float32, shape = (None, obs_dim[0]), name = "input")
# A place holder for actions in a full episode
actions = tf.placeholder(tf.float32, shape = (None, num_actions), name = "actions")
# A place holder for discounted rewards in a full episode
dis_rewards = tf.placeholder(tf.float32, shape = (None, ), name = "dis_rewards")

'''Fully connected layers'''
with tf.name_scope("FC1"):
    fc1 = tf.layers.dense(inputs = input_, units = num_Hidden ,activation = tf.nn.relu, name = "fc1" )

with tf.name_scope("FC2"):
    fc2 = tf.layers.dense(inputs = fc1, units = num_actions ,activation = None, name = "fc2" )

with tf.name_scope("Action_PDF"):
    # Operate with softmax on fc2 outputs to get an action probability distribution
    action_prob_dist = tf.nn.softmax(logits = fc2, name = "softamx")

with tf.name_scope("Loss"):
    '''Define loss'''
    # Fist define reular softmax cross entropy loss
    CE_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels = actions, logits = fc2, name = "CE_loss")
    # Modulate the loss based on our discounted reward - this is where reinforcment learning happens,
    # we favor actions that produced high reward
    loss = tf.reduce_mean(CE_loss * dis_rewards)

with tf.name_scope("Training"):
    '''Define optimizer'''
    training_opt = tf.train.AdamOptimizer(learning_rate).minimize(loss)

'''Define saver for saving and restoring model'''
saver = tf.train.Saver()

# %% [markdown]
# Define a writer for saving summaries to TensorBoard:

# %%
# writer = tf.summary.FileWriter("./tensorboard/1/")

# %% [markdown]
# Here is an example of a graph visualization:
#
# <img src="./img/model_graph.png" width="500">
#
# Each block in the graph is expandable and let you see the content inside, for example see an [image](./img/model_graph_loss.png) with expanded loss block.

# %% [markdown]
# ### Train model

# %% [markdown]
# Now that we have a model ready, we can start training it.
#
# Our goal is to achieve a model that uses the current observation to create the best probability distribution function (PDF) for the next action to be taken. This is **not a deterministic model** - the agent has a fine probability to take any action after receiving an observation, with larger probability to take favorable actions.
#
# To achieve that, in each step, we use our model to generate a PDF of actions, draw an action out of it and take the next step.
# When we reach the end of the episode, we compute the episode loss by feeding the observation, action and discounted rewards vectors (which we kept track of). Our optimizer minimizes the loss which makes favorable (unfavorable) actions more probable (less probable) due to the multiplicative factor of the discounted reward. By repeating these steps to each episode, our agent gradually improves its PDF and becomes a better player!

# %%
ep_action, ep_obs, ep_reward = [], [], []  # Allocate space for episode actions, observations and rewards
tot_ep_reward = [] # Total episode reward
mean_reward = []

''' Run TF session '''
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    ''' Run episodes '''
    for ep in range(num_episodes): 
        obs = env.reset()  # Reset and save first observation
        ep_obs.append(obs) # append observation

        ''' Run steps '''
        while True:
            # Propagate forward to compute action probability distribution
            apd = np.squeeze(sess.run(action_prob_dist, feed_dict = {input_ : obs.reshape((1,obs_dim[0]))}))
            action = np.random.choice(np.arange(num_actions), p = apd)   # Sample an action based on the pdf
            obs, reward, done, info = env.step(action)  # Take action and save observation, reward and done boolean
            
            # Convert action to one hot
            action_oh = np.zeros((1,num_actions))
            action_oh[0,action] = 1
            
            ep_action.append(action_oh)  # append action
            ep_obs.append(obs)           # append observation
            ep_reward.append(reward)     # append reward

            if done: 
                # Stack vertically episode parameters to one np.array
                ep_action = np.vstack(ep_action)
                ep_obs = np.vstack(ep_obs)
                ep_reward = np.hstack(ep_reward)

                # Discount rewards
                dis_rewards_arr = discount_rewards(ep_reward)
                # Compute loss and optimize
                sess.run([loss, training_opt],
                         feed_dict = {input_ : ep_obs[:-1], actions : ep_action, dis_rewards : dis_rewards_arr})
                
                tot_ep_reward.append(np.sum(ep_reward))  # Compute total reward for episode
                mean_reward.append(np.mean(tot_ep_reward))
                
                 # print info
                print("-------------------------------------------------")
                print("Episode {}".format(ep))
                print("Episode ended after {} steps".format(ep_action.shape[0]))
                print("Accumulated reward in this episode {}".format(tot_ep_reward[ep]))
                print("Mean reward so far {:0.2f}".format(np.mean(tot_ep_reward)))
                print("Maximal reward so far {}".format(np.max(tot_ep_reward)))
                
                ep_action, ep_obs, ep_reward = [], [], []  # Clear episode values for next episode
                      
                break
                
    saver.save(sess, "models/model.ckpt") # save model for later
#     writer.add_graph(sess.graph) # Save graph for displaying with TensorBoard
env.close()
# Out:
# -------------------------------------------------
# Episode 0
# Episode ended after 73158 steps
# Accumulated reward in this episode -73158.0
# Mean reward so far -73158.00
# Maximal reward so far -73158.0
# -------------------------------------------------
# Episode 1
# Episode ended after 54923 steps
# Accumulated reward in this episode -54923.0
# Mean reward so far -64040.50
# Maximal reward so far -54923.0
# -------------------------------------------------
# Episode 2
# Episode ended after 17934 steps
# Accumulated reward in this episode -17934.0
# Mean reward so far -48671.67
# Maximal reward so far -17934.0
# -------------------------------------------------
# Episode 3
# Episode ended after 1487 steps
# Accumulated reward in this episode -1487.0
# Mean reward so far -36875.50
# Maximal reward so far -1487.0
# -------------------------------------------------
# Episode 4
# Episode ended after 8685 steps
# Accumulated reward in this episode -8685.0
# Mean reward so far -31237.40
# Maximal reward so far -1487.0
# -------------------------------------------------
# Episode 5
# Episode ended after 1347 steps
# Accumulated reward in this episode -1347.0
# Mean reward so far -26255.67
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 6
# Episode ended after 5747 steps
# Accumulated reward in this episode -5747.0
# Mean reward so far -23325.86
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 7
# Episode ended after 2868 steps
# Accumulated reward in this episode -2868.0
# Mean reward so far -20768.62
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 8
# Episode ended after 2474 steps
# Accumulated reward in this episode -2474.0
# Mean reward so far -18735.89
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 9
# Episode ended after 2528 steps
# Accumulated reward in this episode -2528.0
# Mean reward so far -17115.10
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 10
# Episode ended after 2477 steps
# Accumulated reward in this episode -2477.0
# Mean reward so far -15784.36
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 11
# Episode ended after 2319 steps
# Accumulated reward in this episode -2319.0
# Mean reward so far -14662.25
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 12
# Episode ended after 4014 steps
# Accumulated reward in this episode -4014.0
# Mean reward so far -13843.15
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 13
# Episode ended after 5231 steps
# Accumulated reward in this episode -5231.0
# Mean reward so far -13228.00
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 14
# Episode ended after 3807 steps
# Accumulated reward in this episode -3807.0
# Mean reward so far -12599.93
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 15
# Episode ended after 2364 steps
# Accumulated reward in this episode -2364.0
# Mean reward so far -11960.19
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 16
# Episode ended after 4273 steps
# Accumulated reward in this episode -4273.0
# Mean reward so far -11508.00
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 17
# Episode ended after 1536 steps
# Accumulated reward in this episode -1536.0
# Mean reward so far -10954.00
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 18
# Episode ended after 5457 steps
# Accumulated reward in this episode -5457.0
# Mean reward so far -10664.68
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 19
# Episode ended after 2086 steps
# Accumulated reward in this episode -2086.0
# Mean reward so far -10235.75
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 20
# Episode ended after 3084 steps
# Accumulated reward in this episode -3084.0
# Mean reward so far -9895.19
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 21
# Episode ended after 5539 steps
# Accumulated reward in this episode -5539.0
# Mean reward so far -9697.18
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 22
# Episode ended after 4976 steps
# Accumulated reward in this episode -4976.0
# Mean reward so far -9491.91
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 23
# Episode ended after 3427 steps
# Accumulated reward in this episode -3427.0
# Mean reward so far -9239.21
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 24
# Episode ended after 4506 steps
# Accumulated reward in this episode -4506.0
# Mean reward so far -9049.88
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 25
# Episode ended after 5522 steps
# Accumulated reward in this episode -5522.0
# Mean reward so far -8914.19
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 26
# Episode ended after 2913 steps
# Accumulated reward in this episode -2913.0
# Mean reward so far -8691.93
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 27
# Episode ended after 17774 steps
# Accumulated reward in this episode -17774.0
# Mean reward so far -9016.29
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 28
# Episode ended after 5835 steps
# Accumulated reward in this episode -5835.0
# Mean reward so far -8906.59
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 29
# Episode ended after 9104 steps
# Accumulated reward in this episode -9104.0
# Mean reward so far -8913.17
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 30
# Episode ended after 13253 steps
# Accumulated reward in this episode -13253.0
# Mean reward so far -9053.16
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 31
# Episode ended after 9002 steps
# Accumulated reward in this episode -9002.0
# Mean reward so far -9051.56
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 32
# Episode ended after 9128 steps
# Accumulated reward in this episode -9128.0
# Mean reward so far -9053.88
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 33
# Episode ended after 4357 steps
# Accumulated reward in this episode -4357.0
# Mean reward so far -8915.74
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 34
# Episode ended after 8971 steps
# Accumulated reward in this episode -8971.0
# Mean reward so far -8917.31
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 35
# Episode ended after 7527 steps
# Accumulated reward in this episode -7527.0
# Mean reward so far -8878.69
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 36
# Episode ended after 4953 steps
# Accumulated reward in this episode -4953.0
# Mean reward so far -8772.59
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 37
# Episode ended after 7262 steps
# Accumulated reward in this episode -7262.0
# Mean reward so far -8732.84
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 38
# Episode ended after 1985 steps
# Accumulated reward in this episode -1985.0
# Mean reward so far -8559.82
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 39
# Episode ended after 6408 steps
# Accumulated reward in this episode -6408.0
# Mean reward so far -8506.02
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 40
# Episode ended after 5027 steps
# Accumulated reward in this episode -5027.0
# Mean reward so far -8421.17
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 41
# Episode ended after 4019 steps
# Accumulated reward in this episode -4019.0
# Mean reward so far -8316.36
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 42
# Episode ended after 7976 steps
# Accumulated reward in this episode -7976.0
# Mean reward so far -8308.44
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 43
# Episode ended after 6798 steps
# Accumulated reward in this episode -6798.0
# Mean reward so far -8274.11
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 44
# Episode ended after 5360 steps
# Accumulated reward in this episode -5360.0
# Mean reward so far -8209.36
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 45
# Episode ended after 10639 steps
# Accumulated reward in this episode -10639.0
# Mean reward so far -8262.17
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 46
# Episode ended after 4094 steps
# Accumulated reward in this episode -4094.0
# Mean reward so far -8173.49
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 47
# Episode ended after 3451 steps
# Accumulated reward in this episode -3451.0
# Mean reward so far -8075.10
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 48
# Episode ended after 7411 steps
# Accumulated reward in this episode -7411.0
# Mean reward so far -8061.55
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 49
# Episode ended after 3949 steps
# Accumulated reward in this episode -3949.0
# Mean reward so far -7979.30
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 50
# Episode ended after 13937 steps
# Accumulated reward in this episode -13937.0
# Mean reward so far -8096.12
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 51
# Episode ended after 11803 steps
# Accumulated reward in this episode -11803.0
# Mean reward so far -8167.40
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 52
# Episode ended after 1743 steps
# Accumulated reward in this episode -1743.0
# Mean reward so far -8046.19
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 53
# Episode ended after 3299 steps
# Accumulated reward in this episode -3299.0
# Mean reward so far -7958.28
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 54
# Episode ended after 4545 steps
# Accumulated reward in this episode -4545.0
# Mean reward so far -7896.22
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 55
# Episode ended after 5682 steps
# Accumulated reward in this episode -5682.0
# Mean reward so far -7856.68
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 56
# Episode ended after 12961 steps
# Accumulated reward in this episode -12961.0
# Mean reward so far -7946.23
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 57
# Episode ended after 11625 steps
# Accumulated reward in this episode -11625.0
# Mean reward so far -8009.66
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 58
# Episode ended after 8647 steps
# Accumulated reward in this episode -8647.0
# Mean reward so far -8020.46
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 59
# Episode ended after 4998 steps
# Accumulated reward in this episode -4998.0
# Mean reward so far -7970.08
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 60
# Episode ended after 7628 steps
# Accumulated reward in this episode -7628.0
# Mean reward so far -7964.48
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 61
# Episode ended after 4603 steps
# Accumulated reward in this episode -4603.0
# Mean reward so far -7910.26
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 62
# Episode ended after 5808 steps
# Accumulated reward in this episode -5808.0
# Mean reward so far -7876.89
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 63
# Episode ended after 8443 steps
# Accumulated reward in this episode -8443.0
# Mean reward so far -7885.73
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 64
# Episode ended after 7985 steps
# Accumulated reward in this episode -7985.0
# Mean reward so far -7887.26
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 65
# Episode ended after 4359 steps
# Accumulated reward in this episode -4359.0
# Mean reward so far -7833.80
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 66
# Episode ended after 3990 steps
# Accumulated reward in this episode -3990.0
# Mean reward so far -7776.43
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 67
# Episode ended after 3502 steps
# Accumulated reward in this episode -3502.0
# Mean reward so far -7713.57
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 68
# Episode ended after 3093 steps
# Accumulated reward in this episode -3093.0
# Mean reward so far -7646.61
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 69
# Episode ended after 3304 steps
# Accumulated reward in this episode -3304.0
# Mean reward so far -7584.57
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 70
# Episode ended after 3905 steps
# Accumulated reward in this episode -3905.0
# Mean reward so far -7532.75
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 71
# Episode ended after 3656 steps
# Accumulated reward in this episode -3656.0
# Mean reward so far -7478.90
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 72
# Episode ended after 1853 steps
# Accumulated reward in this episode -1853.0
# Mean reward so far -7401.84
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 73
# Episode ended after 3067 steps
# Accumulated reward in this episode -3067.0
# Mean reward so far -7343.26
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 74
# Episode ended after 1830 steps
# Accumulated reward in this episode -1830.0
# Mean reward so far -7269.75
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 75
# Episode ended after 3188 steps
# Accumulated reward in this episode -3188.0
# Mean reward so far -7216.04
# Maximal reward so far -1347.0
# -------------------------------------------------
# Episode 76
# Episode ended after 1009 steps
# Accumulated reward in this episode -1009.0
# Mean reward so far -7135.43
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 77
# Episode ended after 1516 steps
# Accumulated reward in this episode -1516.0
# Mean reward so far -7063.38
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 78
# Episode ended after 3007 steps
# Accumulated reward in this episode -3007.0
# Mean reward so far -7012.04
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 79
# Episode ended after 3090 steps
# Accumulated reward in this episode -3090.0
# Mean reward so far -6963.01
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 80
# Episode ended after 1018 steps
# Accumulated reward in this episode -1018.0
# Mean reward so far -6889.62
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 81
# Episode ended after 2226 steps
# Accumulated reward in this episode -2226.0
# Mean reward so far -6832.74
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 82
# Episode ended after 1511 steps
# Accumulated reward in this episode -1511.0
# Mean reward so far -6768.63
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 83
# Episode ended after 1205 steps
# Accumulated reward in this episode -1205.0
# Mean reward so far -6702.39
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 84
# Episode ended after 2333 steps
# Accumulated reward in this episode -2333.0
# Mean reward so far -6650.99
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 85
# Episode ended after 1224 steps
# Accumulated reward in this episode -1224.0
# Mean reward so far -6587.88
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 86
# Episode ended after 1236 steps
# Accumulated reward in this episode -1236.0
# Mean reward so far -6526.37
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 87
# Episode ended after 1413 steps
# Accumulated reward in this episode -1413.0
# Mean reward so far -6468.26
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 88
# Episode ended after 2410 steps
# Accumulated reward in this episode -2410.0
# Mean reward so far -6422.66
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 89
# Episode ended after 1488 steps
# Accumulated reward in this episode -1488.0
# Mean reward so far -6367.83
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 90
# Episode ended after 1525 steps
# Accumulated reward in this episode -1525.0
# Mean reward so far -6314.62
# Maximal reward so far -1009.0
# -------------------------------------------------
# Episode 91
# Episode ended after 833 steps
# Accumulated reward in this episode -833.0
# Mean reward so far -6255.03
# Maximal reward so far -833.0
# -------------------------------------------------
# Episode 92
# Episode ended after 1139 steps
# Accumulated reward in this episode -1139.0
# Mean reward so far -6200.02
# Maximal reward so far -833.0
# -------------------------------------------------
# Episode 93
# Episode ended after 1151 steps
# Accumulated reward in this episode -1151.0
# Mean reward so far -6146.31
# Maximal reward so far -833.0
# -------------------------------------------------
# Episode 94
# Episode ended after 997 steps
# Accumulated reward in this episode -997.0
# Mean reward so far -6092.11
# Maximal reward so far -833.0
# -------------------------------------------------
# Episode 95
# Episode ended after 1247 steps
# Accumulated reward in this episode -1247.0
# Mean reward so far -6041.64
# Maximal reward so far -833.0
# -------------------------------------------------
# Episode 96
# Episode ended after 881 steps
# Accumulated reward in this episode -881.0
# Mean reward so far -5988.43
# Maximal reward so far -833.0
# -------------------------------------------------
# Episode 97
# Episode ended after 2594 steps
# Accumulated reward in this episode -2594.0
# Mean reward so far -5953.80
# Maximal reward so far -833.0
# -------------------------------------------------
# Episode 98
# Episode ended after 1445 steps
# Accumulated reward in this episode -1445.0
# Mean reward so far -5908.25
# Maximal reward so far -833.0
# -------------------------------------------------
# Episode 99
# Episode ended after 1997 steps
# Accumulated reward in this episode -1997.0
# Mean reward so far -5869.14
# Maximal reward so far -833.0

# %% [markdown]
# ### Assess model performance

# %% [markdown]
# In order to get a sense of how good our model is, and to see if our agent improves in the training process, we can plot the mean rewards gained in one episode over the episode number. This value would grow as our agent becomes more skilled and gains more rewards in each episode.

# %%
plt.figure(figsize=(8,4))
plt.plot(mean_reward)
plt.xlabel("episode", fontsize=14)
plt.ylabel("mean reward", fontsize = 14)
plt.title("Mean episode rewards over episode number", fontsize = 16)
plt.grid()

# %% [markdown]
# ### Watch the agent play an episode

# %% [markdown]
# This is the fun part!
# Now we get to see how good our agent really is by watching it play an episode. I also record the episode using the Monitor wrapper and limit the number of steps for this episode to 500, because this skilled agent can play forever...

# %%
env = gym.make('MountainCar-v0')
env._max_episode_steps = 500
# env = gym.wrappers.Monitor(env, "recording")
with tf.Session() as sess:
    saver.restore(sess, "models/model.ckpt") # load model
    obs = env.reset() # Reset env and save observation
    t = 0
    while True:
        env.render() # Render game
        # Use our model to create a probability distribution of actions based on observation
        apd = np.squeeze(sess.run(action_prob_dist, feed_dict={input_ : obs.reshape((1,obs_dim[0]))}))
        # Choose an action out of the PDF and take action
        action = np.random.choice(np.arange(num_actions), p = apd)
        obs, reward, done, info = env.step(action)
        t = t+1
        if done:
            print("Game ended after {} steps".format(t+1))
            break
env.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# INFO:tensorflow:Restoring parameters from models/model.ckpt
# Game ended after 461 steps
