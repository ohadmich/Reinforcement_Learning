# %% [markdown]
# # Reinforcement Learning for Lunar Lander game

# %% [markdown]
# Import libraries:

# %%
import numpy as np
import tensorflow as tf
import gym
import matplotlib.pyplot as plt
% matplotlib notebook
# Out:
# c:\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### Defining hyperparameters:

# %% [markdown]
# Here we define all the hyperparameters for the model, this will allow as to easily iterate and find the values that give best results.

# %%
num_episodes = 600      # Number of episodes for training
learning_rate = 0.01
gamma = 0.99           # Discount factor for reward
num_Hidden = 200       # number of nodes in the hidden layer

env = gym.make('LunarLander-v2')    # Choose a game and create an environment
# env = env.unwrapped              # The wrapper limits the number of steps in an episode to 200, let's get rid of it
obs_dim = env.reset().shape      # obervation dimension
num_actions = env.action_space.n # number of actions (this works only for descrete action space, which is the case here)

# %% [markdown]
# ### Define functions

# %% [markdown]
# **Discount reward function**: We we'll train our agent based on the reward gained for his actions. For each action we'll define the episode reward as the total reward gained in all the next steps of the current episode. Since a reward gained further away in the future has less correlation to the present action, we will give it less weight by discounting future rewards.
#
# The formula for the discounted rewards is given by:
#
# $$ R_t = \sum_k \gamma^k r_{t+k} $$
#
# Where $r_t$ is the reward gained in the step $t$ and $\gamma \in [0,1]$ is a hyperparameter called the discount factor.
# Here we define a function that takes a vector of rewards in consequent steps and returns the discounted reward vector:

# %%
def discount_rewards(r):
    '''Takes a 1D rewards (one episode) and discounts it and also standardize
    the rewards to be unit normal (helps control the gradient estimator variance)'''
    
    # Discounting
    dis_r = np.zeros_like(r)
    running_sum = 0
    for t in reversed(range(len(r))):
        running_sum = gamma*running_sum + r[t]
        dis_r[t] = running_sum
    
    # Normailzing
    dis_r = (dis_r - np.mean(dis_r))/np.std(dis_r)
        
    return dis_r

# %% [markdown]
# ### Build model

# %% [markdown]
# To keep order in our model, we use name scopes which basically group the layers of our model in a simple to follow way. Eventually, when using [TensorBoard](https://www.tensorflow.org/guide/summaries_and_tensorboard) for visualizing the model, the graph is more readable and makes it easy to understand the model and find errors.

# %%
'''Create placeholders for inputs'''
# A place holder for input observations
input_ = tf.placeholder(tf.float32, shape = (None, obs_dim[0]), name = "input")
# A place holder for actions in a full episode
actions = tf.placeholder(tf.float32, shape = (None, num_actions), name = "actions")
# A place holder for discounted rewards in a full episode
dis_rewards = tf.placeholder(tf.float32, shape = (None, ), name = "dis_rewards")

'''Fully connected layers'''
with tf.name_scope("FC1"):
    fc1 = tf.layers.dense(inputs = input_, units = num_Hidden ,activation = tf.nn.relu, name = "fc1" )

with tf.name_scope("FC2"):
    fc2 = tf.layers.dense(inputs = fc1, units = num_actions ,activation = None, name = "fc2" )

with tf.name_scope("Action_PDF"):
    # Operate with softmax on fc2 outputs to get an action probability distribution
    action_prob_dist = tf.nn.softmax(logits = fc2, name = "softamx")

with tf.name_scope("Loss"):
    '''Define loss'''
    # Fist define reular softmax cross entropy loss
    CE_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels = actions, logits = fc2, name = "CE_loss")
    # Modulate the loss based on our discounted reward - this is where reinforcment learning happens,
    # we favor actions that produced high reward
    loss = tf.reduce_mean(CE_loss * dis_rewards)

with tf.name_scope("Training"):
    '''Define optimizer'''
    training_opt = tf.train.AdamOptimizer(learning_rate).minimize(loss)

'''Define saver for saving and restoring model'''
saver = tf.train.Saver()

# %% [markdown]
# Define a writer for saving summaries to TensorBoard:

# %%
# writer = tf.summary.FileWriter("./tensorboard/1/")

# %% [markdown]
# Here is an example of a graph visualization:
#
# <img src="./img/model_graph.png" width="500">
#
# Each block in the graph is expandable and let you see the content inside, for example see an [image](./img/model_graph_loss.png) with expanded loss block.

# %% [markdown]
# ### Train model

# %% [markdown]
# Now that we have a model ready, we can start training it.
#
# Our goal is to achieve a model that uses the current observation to create the best probability distribution function (PDF) for the next action to be taken. This is **not a deterministic model** - the agent has a fine probability to take any action after receiving an observation, with larger probability to take favorable actions.
#
# To achieve that, in each step, we use our model to generate a PDF of actions, draw an action out of it and take the next step.
# When we reach the end of the episode, we compute the episode loss by feeding the observation, action and discounted rewards vectors (which we kept track of). Our optimizer minimizes the loss which makes favorable (unfavorable) actions more probable (less probable) due to the multiplicative factor of the discounted reward. By repeating these steps to each episode, our agent gradually improves its PDF and becomes a better player!

# %%
ep_action, ep_obs, ep_reward = [], [], []  # Allocate space for episode actions, observations and rewards
tot_ep_reward = [] # Total episode reward
mean_reward = []

''' Run TF session '''
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    ''' Run episodes '''
    for ep in range(num_episodes): 
        obs = env.reset()  # Reset and save first observation
        ep_obs.append(obs) # append observation

        ''' Run steps '''
        while True:
            # Propagate forward to compute action probability distribution
            apd = np.squeeze(sess.run(action_prob_dist, feed_dict = {input_ : obs.reshape((1,obs_dim[0]))}))
            action = np.random.choice(np.arange(num_actions), p = apd)   # Sample an action based on the pdf
            obs, reward, done, info = env.step(action)  # Take action and save observation, reward and done boolean
            
            # Convert action to one hot
            action_oh = np.zeros((1,num_actions))
            action_oh[0,action] = 1
            
            ep_action.append(action_oh)  # append action
            ep_obs.append(obs)           # append observation
            ep_reward.append(reward)     # append reward

            if done: 
                # Stack vertically episode parameters to one np.array
                ep_action = np.vstack(ep_action)
                ep_obs = np.vstack(ep_obs)
                ep_reward = np.hstack(ep_reward)

                # Discount rewards
                dis_rewards_arr = discount_rewards(ep_reward)
                # Compute loss and optimize
                sess.run([loss, training_opt],
                         feed_dict = {input_ : ep_obs[:-1], actions : ep_action, dis_rewards : dis_rewards_arr})
                
                tot_ep_reward.append(np.sum(ep_reward))  # Compute total reward for episode
                mean_reward.append(np.mean(tot_ep_reward))
                
                 # print info
                print("-------------------------------------------------")
                print("Episode {}".format(ep))
                print("Episode ended after {} steps".format(ep_action.shape[0]))
                print("Accumulated reward in this episode {}".format(tot_ep_reward[ep]))
                print("Mean reward so far {:0.2f}".format(np.mean(tot_ep_reward)))
                print("Maximal reward so far {}".format(np.max(tot_ep_reward)))
                
                ep_action, ep_obs, ep_reward = [], [], []  # Clear episode values for next episode
                      
                break
                
    saver.save(sess, "models/LunarLander/model.ckpt") # save model for later
#     writer.add_graph(sess.graph) # Save graph for displaying with TensorBoard
env.close()
# Out:
# -------------------------------------------------
# Episode 0
# Episode ended after 95 steps
# Accumulated reward in this episode -129.06520027485914
# Mean reward so far -129.07
# Maximal reward so far -129.06520027485914
# -------------------------------------------------
# Episode 1
# Episode ended after 101 steps
# Accumulated reward in this episode -277.9736983631059
# Mean reward so far -203.52
# Maximal reward so far -129.06520027485914
# -------------------------------------------------
# Episode 2
# Episode ended after 108 steps
# Accumulated reward in this episode -375.4264013460406
# Mean reward so far -260.82
# Maximal reward so far -129.06520027485914
# -------------------------------------------------
# Episode 3
# Episode ended after 108 steps
# Accumulated reward in this episode -420.04180521428316
# Mean reward so far -300.63
# Maximal reward so far -129.06520027485914
# -------------------------------------------------
# Episode 4
# Episode ended after 89 steps
# Accumulated reward in this episode -103.57461487266372
# Mean reward so far -261.22
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 5
# Episode ended after 102 steps
# Accumulated reward in this episode -137.87587647688977
# Mean reward so far -240.66
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 6
# Episode ended after 88 steps
# Accumulated reward in this episode -468.13624974915865
# Mean reward so far -273.16
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 7
# Episode ended after 82 steps
# Accumulated reward in this episode -232.88387793581023
# Mean reward so far -268.12
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 8
# Episode ended after 107 steps
# Accumulated reward in this episode -188.38082243521623
# Mean reward so far -259.26
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 9
# Episode ended after 95 steps
# Accumulated reward in this episode -597.0191682777038
# Mean reward so far -293.04
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 10
# Episode ended after 130 steps
# Accumulated reward in this episode -688.5054937128938
# Mean reward so far -328.99
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 11
# Episode ended after 128 steps
# Accumulated reward in this episode -330.13738471591716
# Mean reward so far -329.09
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 12
# Episode ended after 186 steps
# Accumulated reward in this episode -505.2424021515477
# Mean reward so far -342.64
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 13
# Episode ended after 120 steps
# Accumulated reward in this episode -583.8850057281459
# Mean reward so far -359.87
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 14
# Episode ended after 77 steps
# Accumulated reward in this episode -472.1668258990227
# Mean reward so far -367.35
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 15
# Episode ended after 96 steps
# Accumulated reward in this episode -372.04672979591527
# Mean reward so far -367.65
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 16
# Episode ended after 94 steps
# Accumulated reward in this episode -592.5750089803118
# Mean reward so far -380.88
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 17
# Episode ended after 114 steps
# Accumulated reward in this episode -592.2594959666185
# Mean reward so far -392.62
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 18
# Episode ended after 122 steps
# Accumulated reward in this episode -545.8746791797986
# Mean reward so far -400.69
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 19
# Episode ended after 197 steps
# Accumulated reward in this episode -1281.0714916302409
# Mean reward so far -444.71
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 20
# Episode ended after 91 steps
# Accumulated reward in this episode -482.76638258802654
# Mean reward so far -446.52
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 21
# Episode ended after 96 steps
# Accumulated reward in this episode -403.89322583078626
# Mean reward so far -444.58
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 22
# Episode ended after 129 steps
# Accumulated reward in this episode -262.33738597497364
# Mean reward so far -436.66
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 23
# Episode ended after 183 steps
# Accumulated reward in this episode -837.2169257555298
# Mean reward so far -453.35
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 24
# Episode ended after 203 steps
# Accumulated reward in this episode -400.0347504035733
# Mean reward so far -451.22
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 25
# Episode ended after 163 steps
# Accumulated reward in this episode -804.3279311207982
# Mean reward so far -464.80
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 26
# Episode ended after 89 steps
# Accumulated reward in this episode -563.6800592262493
# Mean reward so far -468.46
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 27
# Episode ended after 215 steps
# Accumulated reward in this episode -865.7288009810406
# Mean reward so far -482.65
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 28
# Episode ended after 96 steps
# Accumulated reward in this episode -616.4474966948733
# Mean reward so far -487.26
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 29
# Episode ended after 118 steps
# Accumulated reward in this episode -168.76842471693277
# Mean reward so far -476.64
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 30
# Episode ended after 96 steps
# Accumulated reward in this episode -415.83826675852987
# Mean reward so far -474.68
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 31
# Episode ended after 176 steps
# Accumulated reward in this episode -625.7591329130976
# Mean reward so far -479.40
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 32
# Episode ended after 179 steps
# Accumulated reward in this episode -648.8092897322388
# Mean reward so far -484.54
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 33
# Episode ended after 163 steps
# Accumulated reward in this episode -671.4512972705809
# Mean reward so far -490.04
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 34
# Episode ended after 92 steps
# Accumulated reward in this episode -478.3694751546349
# Mean reward so far -489.70
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 35
# Episode ended after 140 steps
# Accumulated reward in this episode -726.9251057311207
# Mean reward so far -496.29
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 36
# Episode ended after 124 steps
# Accumulated reward in this episode -559.512784222434
# Mean reward so far -498.00
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 37
# Episode ended after 145 steps
# Accumulated reward in this episode -617.642729114273
# Mean reward so far -501.15
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 38
# Episode ended after 136 steps
# Accumulated reward in this episode -767.2106614119939
# Mean reward so far -507.97
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 39
# Episode ended after 162 steps
# Accumulated reward in this episode -668.9062429334114
# Mean reward so far -511.99
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 40
# Episode ended after 87 steps
# Accumulated reward in this episode -581.271208735287
# Mean reward so far -513.68
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 41
# Episode ended after 134 steps
# Accumulated reward in this episode -620.9623534848786
# Mean reward so far -516.24
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 42
# Episode ended after 140 steps
# Accumulated reward in this episode -511.8472246004904
# Mean reward so far -516.14
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 43
# Episode ended after 102 steps
# Accumulated reward in this episode -742.9614445066986
# Mean reward so far -521.29
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 44
# Episode ended after 107 steps
# Accumulated reward in this episode -488.88770323248104
# Mean reward so far -520.57
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 45
# Episode ended after 95 steps
# Accumulated reward in this episode -638.3860677064632
# Mean reward so far -523.13
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 46
# Episode ended after 108 steps
# Accumulated reward in this episode -214.01528780052158
# Mean reward so far -516.56
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 47
# Episode ended after 86 steps
# Accumulated reward in this episode -666.2926501814907
# Mean reward so far -519.67
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 48
# Episode ended after 131 steps
# Accumulated reward in this episode -659.5421070295229
# Mean reward so far -522.53
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 49
# Episode ended after 130 steps
# Accumulated reward in this episode -800.6665588691646
# Mean reward so far -528.09
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 50
# Episode ended after 132 steps
# Accumulated reward in this episode -756.1138312249586
# Mean reward so far -532.56
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 51
# Episode ended after 85 steps
# Accumulated reward in this episode -633.0025699180567
# Mean reward so far -534.49
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 52
# Episode ended after 79 steps
# Accumulated reward in this episode -559.4995138866632
# Mean reward so far -534.97
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 53
# Episode ended after 141 steps
# Accumulated reward in this episode -774.1702499585689
# Mean reward so far -539.40
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 54
# Episode ended after 148 steps
# Accumulated reward in this episode -781.0146556384013
# Mean reward so far -543.79
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 55
# Episode ended after 150 steps
# Accumulated reward in this episode -925.5114380343651
# Mean reward so far -550.61
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 56
# Episode ended after 104 steps
# Accumulated reward in this episode -383.95018715135075
# Mean reward so far -547.68
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 57
# Episode ended after 191 steps
# Accumulated reward in this episode -1324.5152188658083
# Mean reward so far -561.08
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 58
# Episode ended after 74 steps
# Accumulated reward in this episode -527.9804887938365
# Mean reward so far -560.51
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 59
# Episode ended after 105 steps
# Accumulated reward in this episode -540.8907753146993
# Mean reward so far -560.19
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 60
# Episode ended after 164 steps
# Accumulated reward in this episode -925.7843772931963
# Mean reward so far -566.18
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 61
# Episode ended after 110 steps
# Accumulated reward in this episode -188.7900685318407
# Mean reward so far -560.09
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 62
# Episode ended after 80 steps
# Accumulated reward in this episode -662.7789347797832
# Mean reward so far -561.72
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 63
# Episode ended after 169 steps
# Accumulated reward in this episode -866.5949420273305
# Mean reward so far -566.49
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 64
# Episode ended after 189 steps
# Accumulated reward in this episode -1484.2124464743392
# Mean reward so far -580.61
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 65
# Episode ended after 95 steps
# Accumulated reward in this episode -647.4941335678076
# Mean reward so far -581.62
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 66
# Episode ended after 134 steps
# Accumulated reward in this episode -740.8016416273133
# Mean reward so far -584.00
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 67
# Episode ended after 120 steps
# Accumulated reward in this episode -666.4735820787689
# Mean reward so far -585.21
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 68
# Episode ended after 198 steps
# Accumulated reward in this episode -862.1525560730661
# Mean reward so far -589.22
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 69
# Episode ended after 181 steps
# Accumulated reward in this episode -980.9211102855857
# Mean reward so far -594.82
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 70
# Episode ended after 92 steps
# Accumulated reward in this episode -581.0645015306181
# Mean reward so far -594.62
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 71
# Episode ended after 279 steps
# Accumulated reward in this episode -2421.6499805071753
# Mean reward so far -620.00
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 72
# Episode ended after 75 steps
# Accumulated reward in this episode -473.993259289112
# Mean reward so far -618.00
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 73
# Episode ended after 102 steps
# Accumulated reward in this episode -270.6687265546136
# Mean reward so far -613.31
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 74
# Episode ended after 83 steps
# Accumulated reward in this episode -459.3659760505289
# Mean reward so far -611.25
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 75
# Episode ended after 202 steps
# Accumulated reward in this episode -724.4532753388221
# Mean reward so far -612.74
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 76
# Episode ended after 92 steps
# Accumulated reward in this episode -483.4339984627253
# Mean reward so far -611.06
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 77
# Episode ended after 168 steps
# Accumulated reward in this episode -795.6997693711942
# Mean reward so far -613.43
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 78
# Episode ended after 217 steps
# Accumulated reward in this episode -480.457844535024
# Mean reward so far -611.75
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 79
# Episode ended after 161 steps
# Accumulated reward in this episode -135.50012079142024
# Mean reward so far -605.79
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 80
# Episode ended after 206 steps
# Accumulated reward in this episode -457.18938711479785
# Mean reward so far -603.96
# Maximal reward so far -103.57461487266372
# -------------------------------------------------
# Episode 81
# Episode ended after 226 steps
# Accumulated reward in this episode -73.18646450329891
# Mean reward so far -597.49
# Maximal reward so far -73.18646450329891
# -------------------------------------------------
# Episode 82
# Episode ended after 152 steps
# Accumulated reward in this episode -315.4645564914336
# Mean reward so far -594.09
# Maximal reward so far -73.18646450329891
# -------------------------------------------------
# Episode 83
# Episode ended after 118 steps
# Accumulated reward in this episode -175.13313931889974
# Mean reward so far -589.10
# Maximal reward so far -73.18646450329891
# -------------------------------------------------
# Episode 84
# Episode ended after 132 steps
# Accumulated reward in this episode -192.8225393233502
# Mean reward so far -584.44
# Maximal reward so far -73.18646450329891
# -------------------------------------------------
# Episode 85
# Episode ended after 165 steps
# Accumulated reward in this episode 34.60265074352495
# Mean reward so far -577.24
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 86
# Episode ended after 157 steps
# Accumulated reward in this episode -419.6520527683285
# Mean reward so far -575.43
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 87
# Episode ended after 248 steps
# Accumulated reward in this episode -344.1955524066995
# Mean reward so far -572.80
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 88
# Episode ended after 240 steps
# Accumulated reward in this episode -189.9750120147042
# Mean reward so far -568.50
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 89
# Episode ended after 335 steps
# Accumulated reward in this episode -776.631130153794
# Mean reward so far -570.81
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 90
# Episode ended after 126 steps
# Accumulated reward in this episode -373.14146970560444
# Mean reward so far -568.64
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 91
# Episode ended after 243 steps
# Accumulated reward in this episode -638.5005479778085
# Mean reward so far -569.40
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 92
# Episode ended after 344 steps
# Accumulated reward in this episode -669.7769478926077
# Mean reward so far -570.48
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 93
# Episode ended after 139 steps
# Accumulated reward in this episode 10.911937816742984
# Mean reward so far -564.29
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 94
# Episode ended after 144 steps
# Accumulated reward in this episode -656.2621866260902
# Mean reward so far -565.26
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 95
# Episode ended after 122 steps
# Accumulated reward in this episode -702.2860099434217
# Mean reward so far -566.69
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 96
# Episode ended after 287 steps
# Accumulated reward in this episode -348.10800175603515
# Mean reward so far -564.44
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 97
# Episode ended after 194 steps
# Accumulated reward in this episode -258.36057678204236
# Mean reward so far -561.31
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 98
# Episode ended after 200 steps
# Accumulated reward in this episode -514.328169246246
# Mean reward so far -560.84
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 99
# Episode ended after 170 steps
# Accumulated reward in this episode -256.7441466318121
# Mean reward so far -557.80
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 100
# Episode ended after 232 steps
# Accumulated reward in this episode -110.08469876467166
# Mean reward so far -553.37
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 101
# Episode ended after 136 steps
# Accumulated reward in this episode -124.20900158570971
# Mean reward so far -549.16
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 102
# Episode ended after 90 steps
# Accumulated reward in this episode 2.98313134669948
# Mean reward so far -543.80
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 103
# Episode ended after 101 steps
# Accumulated reward in this episode -79.11709208235114
# Mean reward so far -539.33
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 104
# Episode ended after 127 steps
# Accumulated reward in this episode -83.57339749072253
# Mean reward so far -534.99
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 105
# Episode ended after 128 steps
# Accumulated reward in this episode 2.171634817498358
# Mean reward so far -529.92
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 106
# Episode ended after 101 steps
# Accumulated reward in this episode -76.52505413058051
# Mean reward so far -525.68
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 107
# Episode ended after 154 steps
# Accumulated reward in this episode -65.87325861499686
# Mean reward so far -521.43
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 108
# Episode ended after 147 steps
# Accumulated reward in this episode -122.31178216241533
# Mean reward so far -517.76
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 109
# Episode ended after 125 steps
# Accumulated reward in this episode 12.636363626086705
# Mean reward so far -512.94
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 110
# Episode ended after 201 steps
# Accumulated reward in this episode -117.3862426676728
# Mean reward so far -509.38
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 111
# Episode ended after 628 steps
# Accumulated reward in this episode -215.1636757442704
# Mean reward so far -506.75
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 112
# Episode ended after 171 steps
# Accumulated reward in this episode 20.13785148210648
# Mean reward so far -502.09
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 113
# Episode ended after 385 steps
# Accumulated reward in this episode -297.2552305049324
# Mean reward so far -500.29
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 114
# Episode ended after 225 steps
# Accumulated reward in this episode -175.065827601158
# Mean reward so far -497.46
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 115
# Episode ended after 1000 steps
# Accumulated reward in this episode -68.54779057678206
# Mean reward so far -493.77
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 116
# Episode ended after 137 steps
# Accumulated reward in this episode -90.98547322995832
# Mean reward so far -490.32
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 117
# Episode ended after 159 steps
# Accumulated reward in this episode -42.244829908150884
# Mean reward so far -486.53
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 118
# Episode ended after 256 steps
# Accumulated reward in this episode -181.73154611291332
# Mean reward so far -483.97
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 119
# Episode ended after 177 steps
# Accumulated reward in this episode -179.50277989738686
# Mean reward so far -481.43
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 120
# Episode ended after 251 steps
# Accumulated reward in this episode -257.27755751262436
# Mean reward so far -479.58
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 121
# Episode ended after 507 steps
# Accumulated reward in this episode -237.22033735031204
# Mean reward so far -477.59
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 122
# Episode ended after 715 steps
# Accumulated reward in this episode -199.86834252412248
# Mean reward so far -475.33
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 123
# Episode ended after 173 steps
# Accumulated reward in this episode -177.76222156431456
# Mean reward so far -472.93
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 124
# Episode ended after 443 steps
# Accumulated reward in this episode -265.40235495000303
# Mean reward so far -471.27
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 125
# Episode ended after 1000 steps
# Accumulated reward in this episode -17.096005178690547
# Mean reward so far -467.67
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 126
# Episode ended after 1000 steps
# Accumulated reward in this episode 15.72829334831836
# Mean reward so far -463.86
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 127
# Episode ended after 1000 steps
# Accumulated reward in this episode -43.049066996188294
# Mean reward so far -460.57
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 128
# Episode ended after 390 steps
# Accumulated reward in this episode -14.795013579084284
# Mean reward so far -457.12
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 129
# Episode ended after 159 steps
# Accumulated reward in this episode 4.428198384888532
# Mean reward so far -453.57
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 130
# Episode ended after 815 steps
# Accumulated reward in this episode -358.76707021183796
# Mean reward so far -452.84
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 131
# Episode ended after 172 steps
# Accumulated reward in this episode -120.76819665610677
# Mean reward so far -450.33
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 132
# Episode ended after 214 steps
# Accumulated reward in this episode -75.03254743192815
# Mean reward so far -447.51
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 133
# Episode ended after 235 steps
# Accumulated reward in this episode -80.61897906241398
# Mean reward so far -444.77
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 134
# Episode ended after 210 steps
# Accumulated reward in this episode -228.8178353117993
# Mean reward so far -443.17
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 135
# Episode ended after 1000 steps
# Accumulated reward in this episode -55.776238529019864
# Mean reward so far -440.32
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 136
# Episode ended after 156 steps
# Accumulated reward in this episode -219.02315627729902
# Mean reward so far -438.70
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 137
# Episode ended after 222 steps
# Accumulated reward in this episode -160.44764754412947
# Mean reward so far -436.69
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 138
# Episode ended after 118 steps
# Accumulated reward in this episode -68.89042035147936
# Mean reward so far -434.04
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 139
# Episode ended after 114 steps
# Accumulated reward in this episode -25.982756624994366
# Mean reward so far -431.13
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 140
# Episode ended after 1000 steps
# Accumulated reward in this episode -34.458597577122646
# Mean reward so far -428.31
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 141
# Episode ended after 1000 steps
# Accumulated reward in this episode 16.49978842053173
# Mean reward so far -425.18
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 142
# Episode ended after 1000 steps
# Accumulated reward in this episode 17.806903619081453
# Mean reward so far -422.08
# Maximal reward so far 34.60265074352495
# -------------------------------------------------
# Episode 143
# Episode ended after 159 steps
# Accumulated reward in this episode 35.40070481269878
# Mean reward so far -418.91
# Maximal reward so far 35.40070481269878
# -------------------------------------------------
# Episode 144
# Episode ended after 1000 steps
# Accumulated reward in this episode -64.24733619911007
# Mean reward so far -416.46
# Maximal reward so far 35.40070481269878
# -------------------------------------------------
# Episode 145
# Episode ended after 1000 steps
# Accumulated reward in this episode -6.484789572355652
# Mean reward so far -413.65
# Maximal reward so far 35.40070481269878
# -------------------------------------------------
# Episode 146
# Episode ended after 1000 steps
# Accumulated reward in this episode 36.54201515043293
# Mean reward so far -410.59
# Maximal reward so far 36.54201515043293
# -------------------------------------------------
# Episode 147
# Episode ended after 117 steps
# Accumulated reward in this episode -13.713849765708488
# Mean reward so far -407.91
# Maximal reward so far 36.54201515043293
# -------------------------------------------------
# Episode 148
# Episode ended after 136 steps
# Accumulated reward in this episode -4.8411255476632675
# Mean reward so far -405.20
# Maximal reward so far 36.54201515043293
# -------------------------------------------------
# Episode 149
# Episode ended after 169 steps
# Accumulated reward in this episode 62.05641196356837
# Mean reward so far -402.09
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 150
# Episode ended after 1000 steps
# Accumulated reward in this episode -11.409234891109357
# Mean reward so far -399.50
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 151
# Episode ended after 1000 steps
# Accumulated reward in this episode -25.712996307660795
# Mean reward so far -397.04
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 152
# Episode ended after 650 steps
# Accumulated reward in this episode -260.1821146837662
# Mean reward so far -396.15
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 153
# Episode ended after 97 steps
# Accumulated reward in this episode 2.045236388884888
# Mean reward so far -393.56
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 154
# Episode ended after 160 steps
# Accumulated reward in this episode 41.16541198520048
# Mean reward so far -390.76
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 155
# Episode ended after 125 steps
# Accumulated reward in this episode 28.34538926739873
# Mean reward so far -388.07
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 156
# Episode ended after 1000 steps
# Accumulated reward in this episode -11.020140219102984
# Mean reward so far -385.67
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 157
# Episode ended after 1000 steps
# Accumulated reward in this episode -32.36707920231913
# Mean reward so far -383.43
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 158
# Episode ended after 1000 steps
# Accumulated reward in this episode 40.52414146440107
# Mean reward so far -380.77
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 159
# Episode ended after 1000 steps
# Accumulated reward in this episode -21.90115199762819
# Mean reward so far -378.52
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 160
# Episode ended after 1000 steps
# Accumulated reward in this episode -25.689784089418296
# Mean reward so far -376.33
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 161
# Episode ended after 1000 steps
# Accumulated reward in this episode -6.694002188909693
# Mean reward so far -374.05
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 162
# Episode ended after 1000 steps
# Accumulated reward in this episode 4.993650220065554
# Mean reward so far -371.73
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 163
# Episode ended after 1000 steps
# Accumulated reward in this episode -8.940249842319673
# Mean reward so far -369.51
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 164
# Episode ended after 1000 steps
# Accumulated reward in this episode 43.89869487732475
# Mean reward so far -367.01
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 165
# Episode ended after 206 steps
# Accumulated reward in this episode 34.16679329997177
# Mean reward so far -364.59
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 166
# Episode ended after 1000 steps
# Accumulated reward in this episode -36.02220941996842
# Mean reward so far -362.62
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 167
# Episode ended after 1000 steps
# Accumulated reward in this episode -153.51811075800197
# Mean reward so far -361.38
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 168
# Episode ended after 553 steps
# Accumulated reward in this episode -199.34818006382764
# Mean reward so far -360.42
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 169
# Episode ended after 1000 steps
# Accumulated reward in this episode -8.016296466052893
# Mean reward so far -358.35
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 170
# Episode ended after 1000 steps
# Accumulated reward in this episode -118.70318890208742
# Mean reward so far -356.95
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 171
# Episode ended after 1000 steps
# Accumulated reward in this episode -37.7248016256046
# Mean reward so far -355.09
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 172
# Episode ended after 219 steps
# Accumulated reward in this episode -244.0983311239596
# Mean reward so far -354.45
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 173
# Episode ended after 255 steps
# Accumulated reward in this episode 12.477654479158431
# Mean reward so far -352.34
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 174
# Episode ended after 1000 steps
# Accumulated reward in this episode -1.5087387404939072
# Mean reward so far -350.33
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 175
# Episode ended after 1000 steps
# Accumulated reward in this episode -40.39325298645167
# Mean reward so far -348.57
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 176
# Episode ended after 1000 steps
# Accumulated reward in this episode -24.722773309386938
# Mean reward so far -346.74
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 177
# Episode ended after 1000 steps
# Accumulated reward in this episode 2.204306877541981
# Mean reward so far -344.78
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 178
# Episode ended after 1000 steps
# Accumulated reward in this episode -74.01404304910855
# Mean reward so far -343.27
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 179
# Episode ended after 1000 steps
# Accumulated reward in this episode 22.574546694285715
# Mean reward so far -341.24
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 180
# Episode ended after 488 steps
# Accumulated reward in this episode -100.84393025882085
# Mean reward so far -339.91
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 181
# Episode ended after 1000 steps
# Accumulated reward in this episode 21.987597320977926
# Mean reward so far -337.92
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 182
# Episode ended after 1000 steps
# Accumulated reward in this episode -36.13200856318318
# Mean reward so far -336.27
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 183
# Episode ended after 1000 steps
# Accumulated reward in this episode 10.254023175197787
# Mean reward so far -334.39
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 184
# Episode ended after 1000 steps
# Accumulated reward in this episode -10.64367116209851
# Mean reward so far -332.64
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 185
# Episode ended after 1000 steps
# Accumulated reward in this episode -47.68289214738056
# Mean reward so far -331.11
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 186
# Episode ended after 1000 steps
# Accumulated reward in this episode -0.4841105010430482
# Mean reward so far -329.34
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 187
# Episode ended after 1000 steps
# Accumulated reward in this episode 20.84437104412558
# Mean reward so far -327.48
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 188
# Episode ended after 1000 steps
# Accumulated reward in this episode -74.95146843218112
# Mean reward so far -326.14
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 189
# Episode ended after 1000 steps
# Accumulated reward in this episode -10.71575131752023
# Mean reward so far -324.48
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 190
# Episode ended after 290 steps
# Accumulated reward in this episode -86.0957591951875
# Mean reward so far -323.23
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 191
# Episode ended after 1000 steps
# Accumulated reward in this episode 39.55478684811041
# Mean reward so far -321.34
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 192
# Episode ended after 1000 steps
# Accumulated reward in this episode 1.3286355878343556
# Mean reward so far -319.67
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 193
# Episode ended after 316 steps
# Accumulated reward in this episode -168.2931809924064
# Mean reward so far -318.89
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 194
# Episode ended after 1000 steps
# Accumulated reward in this episode 6.180577893094181
# Mean reward so far -317.22
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 195
# Episode ended after 356 steps
# Accumulated reward in this episode -190.16468874236648
# Mean reward so far -316.58
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 196
# Episode ended after 1000 steps
# Accumulated reward in this episode -32.84280212526558
# Mean reward so far -315.14
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 197
# Episode ended after 1000 steps
# Accumulated reward in this episode -5.907988666318531
# Mean reward so far -313.57
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 198
# Episode ended after 1000 steps
# Accumulated reward in this episode -56.41331768929769
# Mean reward so far -312.28
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 199
# Episode ended after 1000 steps
# Accumulated reward in this episode -8.675276878995916
# Mean reward so far -310.76
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 200
# Episode ended after 1000 steps
# Accumulated reward in this episode -79.00281947422305
# Mean reward so far -309.61
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 201
# Episode ended after 1000 steps
# Accumulated reward in this episode -43.58630324880521
# Mean reward so far -308.29
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 202
# Episode ended after 139 steps
# Accumulated reward in this episode 6.240449580770633
# Mean reward so far -306.74
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 203
# Episode ended after 1000 steps
# Accumulated reward in this episode -18.367818881231415
# Mean reward so far -305.33
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 204
# Episode ended after 1000 steps
# Accumulated reward in this episode -44.168811073011824
# Mean reward so far -304.06
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 205
# Episode ended after 1000 steps
# Accumulated reward in this episode 12.657594230734361
# Mean reward so far -302.52
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 206
# Episode ended after 1000 steps
# Accumulated reward in this episode 22.777806181317217
# Mean reward so far -300.95
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 207
# Episode ended after 1000 steps
# Accumulated reward in this episode 23.155708865994015
# Mean reward so far -299.39
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 208
# Episode ended after 129 steps
# Accumulated reward in this episode 19.9177807826589
# Mean reward so far -297.86
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 209
# Episode ended after 1000 steps
# Accumulated reward in this episode 44.156121564208725
# Mean reward so far -296.23
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 210
# Episode ended after 1000 steps
# Accumulated reward in this episode 12.472495217735627
# Mean reward so far -294.77
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 211
# Episode ended after 1000 steps
# Accumulated reward in this episode -0.6047886173410859
# Mean reward so far -293.38
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 212
# Episode ended after 1000 steps
# Accumulated reward in this episode -45.344776538580064
# Mean reward so far -292.22
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 213
# Episode ended after 1000 steps
# Accumulated reward in this episode -46.78242328295124
# Mean reward so far -291.07
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 214
# Episode ended after 1000 steps
# Accumulated reward in this episode 10.264931213358146
# Mean reward so far -289.67
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 215
# Episode ended after 1000 steps
# Accumulated reward in this episode -48.13654560067681
# Mean reward so far -288.55
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 216
# Episode ended after 183 steps
# Accumulated reward in this episode -199.85128922279313
# Mean reward so far -288.14
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 217
# Episode ended after 1000 steps
# Accumulated reward in this episode -24.990304867749614
# Mean reward so far -286.93
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 218
# Episode ended after 1000 steps
# Accumulated reward in this episode -45.280922005498695
# Mean reward so far -285.83
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 219
# Episode ended after 1000 steps
# Accumulated reward in this episode -101.33846680196149
# Mean reward so far -284.99
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 220
# Episode ended after 292 steps
# Accumulated reward in this episode -315.8922309655263
# Mean reward so far -285.13
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 221
# Episode ended after 648 steps
# Accumulated reward in this episode -182.12372768310874
# Mean reward so far -284.67
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 222
# Episode ended after 425 steps
# Accumulated reward in this episode -56.80246287158931
# Mean reward so far -283.65
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 223
# Episode ended after 1000 steps
# Accumulated reward in this episode -23.13526189208595
# Mean reward so far -282.48
# Maximal reward so far 62.05641196356837
# -------------------------------------------------
# Episode 224
# Episode ended after 418 steps
# Accumulated reward in this episode -45.2882073815368
# ...
# Episode 525
# Episode ended after 1000 steps
# Accumulated reward in this episode -13.50309792831536
# Mean reward so far -147.11
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 526
# Episode ended after 1000 steps
# Accumulated reward in this episode -11.405949498580433
# Mean reward so far -146.85
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 527
# Episode ended after 1000 steps
# Accumulated reward in this episode -0.8652628977539862
# Mean reward so far -146.57
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 528
# Episode ended after 1000 steps
# Accumulated reward in this episode -42.47520324306889
# Mean reward so far -146.38
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 529
# Episode ended after 1000 steps
# Accumulated reward in this episode -8.866131199019378
# Mean reward so far -146.12
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 530
# Episode ended after 1000 steps
# Accumulated reward in this episode -18.54613657098772
# Mean reward so far -145.88
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 531
# Episode ended after 1000 steps
# Accumulated reward in this episode -7.767718392506691
# Mean reward so far -145.62
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 532
# Episode ended after 1000 steps
# Accumulated reward in this episode 3.637626851861924
# Mean reward so far -145.34
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 533
# Episode ended after 1000 steps
# Accumulated reward in this episode 45.3845554453996
# Mean reward so far -144.98
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 534
# Episode ended after 1000 steps
# Accumulated reward in this episode 20.391631447488955
# Mean reward so far -144.67
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 535
# Episode ended after 1000 steps
# Accumulated reward in this episode 7.0318801054468025
# Mean reward so far -144.39
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 536
# Episode ended after 1000 steps
# Accumulated reward in this episode -4.625240808781044
# Mean reward so far -144.13
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 537
# Episode ended after 1000 steps
# Accumulated reward in this episode 8.390708067672882
# Mean reward so far -143.84
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 538
# Episode ended after 1000 steps
# Accumulated reward in this episode 23.910279417123576
# Mean reward so far -143.53
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 539
# Episode ended after 1000 steps
# Accumulated reward in this episode 1.3179161327558546
# Mean reward so far -143.26
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 540
# Episode ended after 1000 steps
# Accumulated reward in this episode 13.033498999743955
# Mean reward so far -142.98
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 541
# Episode ended after 1000 steps
# Accumulated reward in this episode -17.359129437259618
# Mean reward so far -142.74
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 542
# Episode ended after 1000 steps
# Accumulated reward in this episode 15.21770817968958
# Mean reward so far -142.45
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 543
# Episode ended after 1000 steps
# Accumulated reward in this episode 31.4057674262273
# Mean reward so far -142.13
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 544
# Episode ended after 1000 steps
# Accumulated reward in this episode -46.572308991809976
# Mean reward so far -141.96
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 545
# Episode ended after 351 steps
# Accumulated reward in this episode -30.94868441358281
# Mean reward so far -141.76
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 546
# Episode ended after 1000 steps
# Accumulated reward in this episode 6.2750491035512255
# Mean reward so far -141.48
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 547
# Episode ended after 1000 steps
# Accumulated reward in this episode -23.689150574982257
# Mean reward so far -141.27
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 548
# Episode ended after 1000 steps
# Accumulated reward in this episode 7.231052061081215
# Mean reward so far -141.00
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 549
# Episode ended after 1000 steps
# Accumulated reward in this episode 32.613097321084396
# Mean reward so far -140.68
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 550
# Episode ended after 1000 steps
# Accumulated reward in this episode -38.93257300912106
# Mean reward so far -140.50
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 551
# Episode ended after 1000 steps
# Accumulated reward in this episode -7.804024676152743
# Mean reward so far -140.26
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 552
# Episode ended after 1000 steps
# Accumulated reward in this episode 31.1967639074266
# Mean reward so far -139.95
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 553
# Episode ended after 1000 steps
# Accumulated reward in this episode -46.71811916805103
# Mean reward so far -139.78
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 554
# Episode ended after 1000 steps
# Accumulated reward in this episode -19.360121202898306
# Mean reward so far -139.56
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 555
# Episode ended after 1000 steps
# Accumulated reward in this episode 6.604916648036948
# Mean reward so far -139.30
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 556
# Episode ended after 1000 steps
# Accumulated reward in this episode 4.745812026240003
# Mean reward so far -139.04
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 557
# Episode ended after 1000 steps
# Accumulated reward in this episode 35.80807109244253
# Mean reward so far -138.73
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 558
# Episode ended after 1000 steps
# Accumulated reward in this episode -4.059573391852993
# Mean reward so far -138.49
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 559
# Episode ended after 1000 steps
# Accumulated reward in this episode -14.718166763274482
# Mean reward so far -138.27
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 560
# Episode ended after 1000 steps
# Accumulated reward in this episode -47.129037061517295
# Mean reward so far -138.10
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 561
# Episode ended after 1000 steps
# Accumulated reward in this episode -48.568273321447116
# Mean reward so far -137.94
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 562
# Episode ended after 1000 steps
# Accumulated reward in this episode -43.8460386672403
# Mean reward so far -137.78
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 563
# Episode ended after 1000 steps
# Accumulated reward in this episode 1.5011658942283361
# Mean reward so far -137.53
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 564
# Episode ended after 487 steps
# Accumulated reward in this episode -191.36042155427066
# Mean reward so far -137.63
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 565
# Episode ended after 188 steps
# Accumulated reward in this episode -5.501453975837478
# Mean reward so far -137.39
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 566
# Episode ended after 1000 steps
# Accumulated reward in this episode -25.572673323299973
# Mean reward so far -137.20
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 567
# Episode ended after 1000 steps
# Accumulated reward in this episode -37.808207354406065
# Mean reward so far -137.02
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 568
# Episode ended after 1000 steps
# Accumulated reward in this episode 23.787414082049068
# Mean reward so far -136.74
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 569
# Episode ended after 1000 steps
# Accumulated reward in this episode -32.286738273549076
# Mean reward so far -136.55
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 570
# Episode ended after 501 steps
# Accumulated reward in this episode -405.20334304115954
# Mean reward so far -137.02
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 571
# Episode ended after 1000 steps
# Accumulated reward in this episode 8.735712094686491
# Mean reward so far -136.77
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 572
# Episode ended after 1000 steps
# Accumulated reward in this episode -30.631227317945545
# Mean reward so far -136.58
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 573
# Episode ended after 1000 steps
# Accumulated reward in this episode -48.727702940469385
# Mean reward so far -136.43
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 574
# Episode ended after 1000 steps
# Accumulated reward in this episode 11.912130304407896
# Mean reward so far -136.17
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 575
# Episode ended after 1000 steps
# Accumulated reward in this episode 0.07323924369164558
# Mean reward so far -135.94
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 576
# Episode ended after 1000 steps
# Accumulated reward in this episode -42.791330931033315
# Mean reward so far -135.78
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 577
# Episode ended after 1000 steps
# Accumulated reward in this episode 24.33058146128943
# Mean reward so far -135.50
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 578
# Episode ended after 842 steps
# Accumulated reward in this episode -394.6250303702134
# Mean reward so far -135.95
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 579
# Episode ended after 564 steps
# Accumulated reward in this episode -401.2723430348614
# Mean reward so far -136.40
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 580
# Episode ended after 1000 steps
# Accumulated reward in this episode -4.200833669269166
# Mean reward so far -136.18
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 581
# Episode ended after 1000 steps
# Accumulated reward in this episode -22.67423129761149
# Mean reward so far -135.98
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 582
# Episode ended after 382 steps
# Accumulated reward in this episode -27.11862278129697
# Mean reward so far -135.79
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 583
# Episode ended after 1000 steps
# Accumulated reward in this episode 20.022085217667303
# Mean reward so far -135.53
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 584
# Episode ended after 1000 steps
# Accumulated reward in this episode -50.9616927242665
# Mean reward so far -135.38
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 585
# Episode ended after 1000 steps
# Accumulated reward in this episode 31.153149780661863
# Mean reward so far -135.10
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 586
# Episode ended after 1000 steps
# Accumulated reward in this episode 29.206412348004577
# Mean reward so far -134.82
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 587
# Episode ended after 1000 steps
# Accumulated reward in this episode -92.31831640471815
# Mean reward so far -134.75
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 588
# Episode ended after 1000 steps
# Accumulated reward in this episode -23.153862350284612
# Mean reward so far -134.56
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 589
# Episode ended after 1000 steps
# Accumulated reward in this episode -17.000100792438133
# Mean reward so far -134.36
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 590
# Episode ended after 1000 steps
# Accumulated reward in this episode 60.8402982918674
# Mean reward so far -134.03
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 591
# Episode ended after 1000 steps
# Accumulated reward in this episode 41.116916572435535
# Mean reward so far -133.73
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 592
# Episode ended after 1000 steps
# Accumulated reward in this episode 4.541142288585974
# Mean reward so far -133.50
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 593
# Episode ended after 1000 steps
# Accumulated reward in this episode 26.539474833800142
# Mean reward so far -133.23
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 594
# Episode ended after 1000 steps
# Accumulated reward in this episode 49.01491915136957
# Mean reward so far -132.92
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 595
# Episode ended after 1000 steps
# Accumulated reward in this episode 16.168648367935162
# Mean reward so far -132.67
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 596
# Episode ended after 1000 steps
# Accumulated reward in this episode -11.602581478331338
# Mean reward so far -132.47
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 597
# Episode ended after 1000 steps
# Accumulated reward in this episode 0.8500973073583253
# Mean reward so far -132.25
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 598
# Episode ended after 1000 steps
# Accumulated reward in this episode 24.260878045379023
# Mean reward so far -131.99
# Maximal reward so far 73.18360941189535
# -------------------------------------------------
# Episode 599
# Episode ended after 1000 steps
# Accumulated reward in this episode 27.900175383118523
# Mean reward so far -131.72
# Maximal reward so far 73.18360941189535

# %% [markdown]
# ### Assess model performance

# %% [markdown]
# In order to get a sense of how good our model is, and to see if our agent improves in the training process, we can plot the mean rewards gained in one episode over the episode number. This value would grow as our agent becomes more skilled and gains more rewards in each episode.

# %%
plt.figure(figsize=(8,4))
plt.plot(mean_reward)
plt.xlabel("episode", fontsize=14)
plt.ylabel("mean reward", fontsize = 14)
plt.title("Mean episode rewards over episode number", fontsize = 16)
plt.grid()

# %% [markdown]
# ### Watch the agent play an episode

# %% [markdown]
# This is the fun part!
# Now we get to see how good our agent really is by watching it play an episode. I also record the episode using the Monitor wrapper and limit the number of steps for this episode to 500, because this skilled agent can play forever...

# %%
ep_reward = []
env = gym.make('LunarLander-v2')
env._max_episode_steps = 500
# env = gym.wrappers.Monitor(env, "recording")
with tf.Session() as sess:
    saver.restore(sess, "models/LunarLander/model.ckpt") # load model
    obs = env.reset() # Reset env and save observation
    t = 0
    while True:
        env.render() # Render game
        # Use our model to create a probability distribution of actions based on observation
        apd = np.squeeze(sess.run(action_prob_dist, feed_dict={input_ : obs.reshape((1,obs_dim[0]))}))
        # Choose an action out of the PDF and take action
        action = np.random.choice(np.arange(num_actions), p = apd)
        obs, reward, done, info = env.step(action)
        ep_reward.append(reward)
        t = t+1
        if done:
            print("Game ended after {} steps".format(t+1))
            print("Total reward earned in this episode: {}".format(sum(ep_reward)))
            break
env.close()
# Out:
# INFO:tensorflow:Restoring parameters from models/LunarLander/model.ckpt
# Game ended after 501 steps
# Total reward earned in this episode: 102.33188900004508

# %% [markdown]
# ### Test the trained model performance

# %%
num_ep = 100
ep_reward = []
batch_reward = []
env = gym.make('LunarLander-v2')
env._max_episode_steps = 500
with tf.Session() as sess:
    saver.restore(sess, "models/LunarLander/model.ckpt") # load model
    for ep in range(num_ep):
        obs = env.reset() # Reset env and save observation
        t = 0
        while True:
            # Use our model to create a probability distribution of actions based on observation
            apd = np.squeeze(sess.run(action_prob_dist, feed_dict={input_ : obs.reshape((1,obs_dim[0]))}))
            # Choose an action out of the PDF and take action
            action = np.random.choice(np.arange(num_actions), p = apd)
            obs, reward, done, info = env.step(action)
            ep_reward.append(reward)
            t = t+1
            if done:
                print("-------------------------------------------")
                print("Game ended after {} steps".format(t+1))
                print("Total reward earned in this episode: {}".format(sum(ep_reward)))
                batch_reward.append(sum(ep_reward))
                ep_reward = []
                break
print("Average reward is {}".format(np.mean(batch_reward)))
# Out:
# INFO:tensorflow:Restoring parameters from models/LunarLander/model.ckpt
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 73.18571216996112
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 180.50268008542213
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 314.84742999611734
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 410.53414376378817
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 498.9719635817764
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 592.8286150219883
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 694.9544872419367
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 788.2548115513371
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 888.203107129421
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 985.234940954912
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 1092.5866026814456
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 1225.0280459632734
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 1331.9668989162362
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 1428.0391627684414
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 1555.9889686077752
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 1631.99752819574
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 1708.0548155475894
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 1776.4837020485718
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 1902.9779515226128
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 2000.4184086040855
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 2099.63207809136
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 2213.29804077289
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 2324.3497874931168
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 2417.4792349366508
# -------------------------------------------
# Game ended after 199 steps
# Total reward earned in this episode: 2297.094557207099
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 2379.948710124218
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 2508.987775202402
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 2606.136761802759
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 2713.534733806893
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 2781.6213246274265
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 2865.783964154316
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 2943.006086548505
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 3083.410644073463
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 3225.6822606140563
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 3337.9934904636166
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 3474.285650797409
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 3542.9718654879352
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 3662.618878532925
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 3808.2723809027693
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 3904.912505469588
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 4012.6729415728123
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 4165.9089050116745
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 4280.070445274127
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 4387.494688110305
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 4449.092929414148
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 4554.404334088937
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 4680.811954375472
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 4762.008180362929
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 4891.362371944851
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 4953.7143643800455
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 5025.787858319003
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 5146.401052358485
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 5271.040954494439
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 5410.629088663752
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 5526.238442755083
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 5600.931016239329
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 5702.376483116864
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 5806.081598173334
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 5890.983550338017
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 5938.387548208949
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 6048.6059895936805
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 6153.922016814363
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 6315.574299866696
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 6410.638737871468
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 6543.550737063581
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 6693.320295387548
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 6805.7739515858075
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 6885.732433736915
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 6973.486497595685
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 7137.8567421067155
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 7243.299478125653
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 7341.268251055841
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 7415.592226689202
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 7507.053597874683
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 7639.569968771445
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 7721.9905135897925
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 7823.6913029118305
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 7952.881421011015
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 8052.589674708787
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 8191.470779936918
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 8297.387191477243
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 8392.508507060646
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 8515.752126517289
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 8600.943297301244
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 8734.115654174528
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 8861.298239653941
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 8981.986421935126
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 9091.805924444341
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 9147.982912611886
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 9255.31821667507
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 9349.769559113342
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 9419.303735766112
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 9471.083632982436
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 9532.514869748462
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 9627.880192499764
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 9721.926961467458
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 9831.121484593297
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 9941.384640406795
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 10002.486077283447
# -------------------------------------------
# Game ended after 501 steps
# Total reward earned in this episode: 10115.881622638812
# Average reward is 5074.787995993133
