# %% [markdown]
# # Reinforcement Learning for Lunar Lander game

# %% [markdown]
# Import libraries:

# %%
import numpy as np
import tensorflow as tf
import gym
import matplotlib.pyplot as plt
% matplotlib notebook
# Out:
# c:\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### Defining hyperparameters:

# %% [markdown]
# Here we define all the hyperparameters for the model, this will allow as to easily iterate and find the values that give best results.

# %%
num_episodes = 200      # Number of episodes for training
learning_rate = 0.001
gamma = 0.99           # Discount factor for reward
num_Hidden = 200       # number of nodes in the hidden layer

env = gym.make('Acrobot-v1')    # Choose a game and create an environment
env = env.unwrapped              # The wrapper limits the number of steps in an episode, let's get rid of it
# env._max_episode_steps = 10000
obs_dim = env.reset().shape      # obervation dimension
num_actions = env.action_space.n # number of actions (this works only for descrete action space, which is the case here)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %% [markdown]
# ### Define functions

# %% [markdown]
# **Discount reward function**: We we'll train our agent based on the reward gained for his actions. For each action we'll define the episode reward as the total reward gained in all the next steps of the current episode. Since a reward gained further away in the future has less correlation to the present action, we will give it less weight by discounting future rewards.
#
# The formula for the discounted rewards is given by:
#
# $$ R_t = \sum_k \gamma^k r_{t+k} $$
#
# Where $r_t$ is the reward gained in the step $t$ and $\gamma \in [0,1]$ is a hyperparameter called the discount factor.
# Here we define a function that takes a vector of rewards in consequent steps and returns the discounted reward vector:

# %%
def discount_rewards(r):
    '''Takes a 1D rewards (one episode) and discounts it and also standardize
    the rewards to be unit normal (helps control the gradient estimator variance)'''
    
    # Discounting
    dis_r = np.zeros_like(r)
    running_sum = 0
    for t in reversed(range(len(r))):
        running_sum = gamma*running_sum + r[t]
        dis_r[t] = running_sum
    
    # Normailzing
    dis_r = (dis_r - np.mean(dis_r))/np.std(dis_r)
        
    return dis_r

# %% [markdown]
# ### Build model

# %% [markdown]
# To keep order in our model, we use name scopes which basically group the layers of our model in a simple to follow way. Eventually, when using [TensorBoard](https://www.tensorflow.org/guide/summaries_and_tensorboard) for visualizing the model, the graph is more readable and makes it easy to understand the model and find errors.

# %%
'''Create placeholders for inputs'''
# A place holder for input observations
input_ = tf.placeholder(tf.float32, shape = (None, obs_dim[0]), name = "input")
# A place holder for actions in a full episode
actions = tf.placeholder(tf.float32, shape = (None, num_actions), name = "actions")
# A place holder for discounted rewards in a full episode
dis_rewards = tf.placeholder(tf.float32, shape = (None, ), name = "dis_rewards")

'''Fully connected layers'''
with tf.name_scope("FC1"):
    fc1 = tf.layers.dense(inputs = input_, units = num_Hidden ,activation = tf.nn.relu, name = "fc1" )

with tf.name_scope("FC2"):
    fc2 = tf.layers.dense(inputs = fc1, units = num_actions ,activation = None, name = "fc2" )

with tf.name_scope("Action_PDF"):
    # Operate with softmax on fc2 outputs to get an action probability distribution
    action_prob_dist = tf.nn.softmax(logits = fc2, name = "softamx")

with tf.name_scope("Loss"):
    '''Define loss'''
    # Fist define reular softmax cross entropy loss
    CE_loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels = actions, logits = fc2, name = "CE_loss")
    # Modulate the loss based on our discounted reward - this is where reinforcment learning happens,
    # we favor actions that produced high reward
    loss = tf.reduce_mean(CE_loss * dis_rewards)

with tf.name_scope("Training"):
    '''Define optimizer'''
    training_opt = tf.train.AdamOptimizer(learning_rate).minimize(loss)

'''Define saver for saving and restoring model'''
saver = tf.train.Saver()

# %% [markdown]
# Define a writer for saving summaries to TensorBoard:

# %%
# writer = tf.summary.FileWriter("./tensorboard/1/")

# %% [markdown]
# Here is an example of a graph visualization:
#
# <img src="./img/model_graph.png" width="500">
#
# Each block in the graph is expandable and let you see the content inside, for example see an [image](./img/model_graph_loss.png) with expanded loss block.

# %% [markdown]
# ### Train model

# %% [markdown]
# Now that we have a model ready, we can start training it.
#
# Our goal is to achieve a model that uses the current observation to create the best probability distribution function (PDF) for the next action to be taken. This is **not a deterministic model** - the agent has a fine probability to take any action after receiving an observation, with larger probability to take favorable actions.
#
# To achieve that, in each step, we use our model to generate a PDF of actions, draw an action out of it and take the next step.
# When we reach the end of the episode, we compute the episode loss by feeding the observation, action and discounted rewards vectors (which we kept track of). Our optimizer minimizes the loss which makes favorable (unfavorable) actions more probable (less probable) due to the multiplicative factor of the discounted reward. By repeating these steps to each episode, our agent gradually improves its PDF and becomes a better player!

# %%
ep_action, ep_obs, ep_reward = [], [], []  # Allocate space for episode actions, observations and rewards
tot_ep_reward = [] # Total episode reward
mean_reward = []

''' Run TF session '''
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    ''' Run episodes '''
    for ep in range(num_episodes): 
        obs = env.reset()  # Reset and save first observation
        ep_obs.append(obs) # append observation

        ''' Run steps '''
        while True:
            # Propagate forward to compute action probability distribution
            apd = np.squeeze(sess.run(action_prob_dist, feed_dict = {input_ : obs.reshape((1,obs_dim[0]))}))
            action = np.random.choice(np.arange(num_actions), p = apd)   # Sample an action based on the pdf
            obs, reward, done, info = env.step(action)  # Take action and save observation, reward and done boolean
            
            # Convert action to one hot
            action_oh = np.zeros((1,num_actions))
            action_oh[0,action] = 1
            
            ep_action.append(action_oh)  # append action
            ep_obs.append(obs)           # append observation
            ep_reward.append(reward)     # append reward

            if done: 
                # Stack vertically episode parameters to one np.array
                ep_action = np.vstack(ep_action)
                ep_obs = np.vstack(ep_obs)
                ep_reward = np.hstack(ep_reward)

                # Discount rewards
                dis_rewards_arr = discount_rewards(ep_reward)
                # Compute loss and optimize
                sess.run([loss, training_opt],
                         feed_dict = {input_ : ep_obs[:-1], actions : ep_action, dis_rewards : dis_rewards_arr})
                
                tot_ep_reward.append(np.sum(ep_reward))  # Compute total reward for episode
                mean_reward.append(np.mean(tot_ep_reward))
                
                 # print info
                print("-------------------------------------------------")
                print("Episode {}".format(ep))
                print("Episode ended after {} steps".format(ep_action.shape[0]))
                print("Accumulated reward in this episode {}".format(tot_ep_reward[ep]))
                print("Mean reward so far {:0.2f}".format(np.mean(tot_ep_reward)))
                print("Maximal reward so far {}".format(np.max(tot_ep_reward)))
                
                ep_action, ep_obs, ep_reward = [], [], []  # Clear episode values for next episode
                      
                break
                
    saver.save(sess, "models/Acrobot/model.ckpt") # save model for later
#     writer.add_graph(sess.graph) # Save graph for displaying with TensorBoard
env.close()
# Out:
# -------------------------------------------------
# Episode 0
# Episode ended after 600 steps
# Accumulated reward in this episode -599.0
# Mean reward so far -599.00
# Maximal reward so far -599.0
# -------------------------------------------------
# Episode 1
# Episode ended after 868 steps
# Accumulated reward in this episode -867.0
# Mean reward so far -733.00
# Maximal reward so far -599.0
# -------------------------------------------------
# Episode 2
# Episode ended after 500 steps
# Accumulated reward in this episode -499.0
# Mean reward so far -655.00
# Maximal reward so far -499.0
# -------------------------------------------------
# Episode 3
# Episode ended after 648 steps
# Accumulated reward in this episode -647.0
# Mean reward so far -653.00
# Maximal reward so far -499.0
# -------------------------------------------------
# Episode 4
# Episode ended after 499 steps
# Accumulated reward in this episode -498.0
# Mean reward so far -622.00
# Maximal reward so far -498.0
# -------------------------------------------------
# Episode 5
# Episode ended after 435 steps
# Accumulated reward in this episode -434.0
# Mean reward so far -590.67
# Maximal reward so far -434.0
# -------------------------------------------------
# Episode 6
# Episode ended after 699 steps
# Accumulated reward in this episode -698.0
# Mean reward so far -606.00
# Maximal reward so far -434.0
# -------------------------------------------------
# Episode 7
# Episode ended after 340 steps
# Accumulated reward in this episode -339.0
# Mean reward so far -572.62
# Maximal reward so far -339.0
# -------------------------------------------------
# Episode 8
# Episode ended after 542 steps
# Accumulated reward in this episode -541.0
# Mean reward so far -569.11
# Maximal reward so far -339.0
# -------------------------------------------------
# Episode 9
# Episode ended after 482 steps
# Accumulated reward in this episode -481.0
# Mean reward so far -560.30
# Maximal reward so far -339.0
# -------------------------------------------------
# Episode 10
# Episode ended after 278 steps
# Accumulated reward in this episode -277.0
# Mean reward so far -534.55
# Maximal reward so far -277.0
# -------------------------------------------------
# Episode 11
# Episode ended after 553 steps
# Accumulated reward in this episode -552.0
# Mean reward so far -536.00
# Maximal reward so far -277.0
# -------------------------------------------------
# Episode 12
# Episode ended after 347 steps
# Accumulated reward in this episode -346.0
# Mean reward so far -521.38
# Maximal reward so far -277.0
# -------------------------------------------------
# Episode 13
# Episode ended after 291 steps
# Accumulated reward in this episode -290.0
# Mean reward so far -504.86
# Maximal reward so far -277.0
# -------------------------------------------------
# Episode 14
# Episode ended after 374 steps
# Accumulated reward in this episode -373.0
# Mean reward so far -496.07
# Maximal reward so far -277.0
# -------------------------------------------------
# Episode 15
# Episode ended after 303 steps
# Accumulated reward in this episode -302.0
# Mean reward so far -483.94
# Maximal reward so far -277.0
# -------------------------------------------------
# Episode 16
# Episode ended after 273 steps
# Accumulated reward in this episode -272.0
# Mean reward so far -471.47
# Maximal reward so far -272.0
# -------------------------------------------------
# Episode 17
# Episode ended after 255 steps
# Accumulated reward in this episode -254.0
# Mean reward so far -459.39
# Maximal reward so far -254.0
# -------------------------------------------------
# Episode 18
# Episode ended after 310 steps
# Accumulated reward in this episode -309.0
# Mean reward so far -451.47
# Maximal reward so far -254.0
# -------------------------------------------------
# Episode 19
# Episode ended after 432 steps
# Accumulated reward in this episode -431.0
# Mean reward so far -450.45
# Maximal reward so far -254.0
# -------------------------------------------------
# Episode 20
# Episode ended after 359 steps
# Accumulated reward in this episode -358.0
# Mean reward so far -446.05
# Maximal reward so far -254.0
# -------------------------------------------------
# Episode 21
# Episode ended after 310 steps
# Accumulated reward in this episode -309.0
# Mean reward so far -439.82
# Maximal reward so far -254.0
# -------------------------------------------------
# Episode 22
# Episode ended after 270 steps
# Accumulated reward in this episode -269.0
# Mean reward so far -432.39
# Maximal reward so far -254.0
# -------------------------------------------------
# Episode 23
# Episode ended after 255 steps
# Accumulated reward in this episode -254.0
# Mean reward so far -424.96
# Maximal reward so far -254.0
# -------------------------------------------------
# Episode 24
# Episode ended after 296 steps
# Accumulated reward in this episode -295.0
# Mean reward so far -419.76
# Maximal reward so far -254.0
# -------------------------------------------------
# Episode 25
# Episode ended after 268 steps
# Accumulated reward in this episode -267.0
# Mean reward so far -413.88
# Maximal reward so far -254.0
# -------------------------------------------------
# Episode 26
# Episode ended after 325 steps
# Accumulated reward in this episode -324.0
# Mean reward so far -410.56
# Maximal reward so far -254.0
# -------------------------------------------------
# Episode 27
# Episode ended after 263 steps
# Accumulated reward in this episode -262.0
# Mean reward so far -405.25
# Maximal reward so far -254.0
# -------------------------------------------------
# Episode 28
# Episode ended after 342 steps
# Accumulated reward in this episode -341.0
# Mean reward so far -403.03
# Maximal reward so far -254.0
# -------------------------------------------------
# Episode 29
# Episode ended after 207 steps
# Accumulated reward in this episode -206.0
# Mean reward so far -396.47
# Maximal reward so far -206.0
# -------------------------------------------------
# Episode 30
# Episode ended after 283 steps
# Accumulated reward in this episode -282.0
# Mean reward so far -392.77
# Maximal reward so far -206.0
# -------------------------------------------------
# Episode 31
# Episode ended after 339 steps
# Accumulated reward in this episode -338.0
# Mean reward so far -391.06
# Maximal reward so far -206.0
# -------------------------------------------------
# Episode 32
# Episode ended after 314 steps
# Accumulated reward in this episode -313.0
# Mean reward so far -388.70
# Maximal reward so far -206.0
# -------------------------------------------------
# Episode 33
# Episode ended after 303 steps
# Accumulated reward in this episode -302.0
# Mean reward so far -386.15
# Maximal reward so far -206.0
# -------------------------------------------------
# Episode 34
# Episode ended after 320 steps
# Accumulated reward in this episode -319.0
# Mean reward so far -384.23
# Maximal reward so far -206.0
# -------------------------------------------------
# Episode 35
# Episode ended after 201 steps
# Accumulated reward in this episode -200.0
# Mean reward so far -379.11
# Maximal reward so far -200.0
# -------------------------------------------------
# Episode 36
# Episode ended after 348 steps
# Accumulated reward in this episode -347.0
# Mean reward so far -378.24
# Maximal reward so far -200.0
# -------------------------------------------------
# Episode 37
# Episode ended after 242 steps
# Accumulated reward in this episode -241.0
# Mean reward so far -374.63
# Maximal reward so far -200.0
# -------------------------------------------------
# Episode 38
# Episode ended after 235 steps
# Accumulated reward in this episode -234.0
# Mean reward so far -371.03
# Maximal reward so far -200.0
# -------------------------------------------------
# Episode 39
# Episode ended after 212 steps
# Accumulated reward in this episode -211.0
# Mean reward so far -367.02
# Maximal reward so far -200.0
# -------------------------------------------------
# Episode 40
# Episode ended after 181 steps
# Accumulated reward in this episode -180.0
# Mean reward so far -362.46
# Maximal reward so far -180.0
# -------------------------------------------------
# Episode 41
# Episode ended after 264 steps
# Accumulated reward in this episode -263.0
# Mean reward so far -360.10
# Maximal reward so far -180.0
# -------------------------------------------------
# Episode 42
# Episode ended after 243 steps
# Accumulated reward in this episode -242.0
# Mean reward so far -357.35
# Maximal reward so far -180.0
# -------------------------------------------------
# Episode 43
# Episode ended after 133 steps
# Accumulated reward in this episode -132.0
# Mean reward so far -352.23
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 44
# Episode ended after 146 steps
# Accumulated reward in this episode -145.0
# Mean reward so far -347.62
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 45
# Episode ended after 353 steps
# Accumulated reward in this episode -352.0
# Mean reward so far -347.72
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 46
# Episode ended after 244 steps
# Accumulated reward in this episode -243.0
# Mean reward so far -345.49
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 47
# Episode ended after 192 steps
# Accumulated reward in this episode -191.0
# Mean reward so far -342.27
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 48
# Episode ended after 224 steps
# Accumulated reward in this episode -223.0
# Mean reward so far -339.84
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 49
# Episode ended after 183 steps
# Accumulated reward in this episode -182.0
# Mean reward so far -336.68
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 50
# Episode ended after 263 steps
# Accumulated reward in this episode -262.0
# Mean reward so far -335.22
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 51
# Episode ended after 217 steps
# Accumulated reward in this episode -216.0
# Mean reward so far -332.92
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 52
# Episode ended after 212 steps
# Accumulated reward in this episode -211.0
# Mean reward so far -330.62
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 53
# Episode ended after 166 steps
# Accumulated reward in this episode -165.0
# Mean reward so far -327.56
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 54
# Episode ended after 277 steps
# Accumulated reward in this episode -276.0
# Mean reward so far -326.62
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 55
# Episode ended after 232 steps
# Accumulated reward in this episode -231.0
# Mean reward so far -324.91
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 56
# Episode ended after 138 steps
# Accumulated reward in this episode -137.0
# Mean reward so far -321.61
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 57
# Episode ended after 192 steps
# Accumulated reward in this episode -191.0
# Mean reward so far -319.36
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 58
# Episode ended after 174 steps
# Accumulated reward in this episode -173.0
# Mean reward so far -316.88
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 59
# Episode ended after 210 steps
# Accumulated reward in this episode -209.0
# Mean reward so far -315.08
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 60
# Episode ended after 172 steps
# Accumulated reward in this episode -171.0
# Mean reward so far -312.72
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 61
# Episode ended after 161 steps
# Accumulated reward in this episode -160.0
# Mean reward so far -310.26
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 62
# Episode ended after 170 steps
# Accumulated reward in this episode -169.0
# Mean reward so far -308.02
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 63
# Episode ended after 245 steps
# Accumulated reward in this episode -244.0
# Mean reward so far -307.02
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 64
# Episode ended after 141 steps
# Accumulated reward in this episode -140.0
# Mean reward so far -304.45
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 65
# Episode ended after 181 steps
# Accumulated reward in this episode -180.0
# Mean reward so far -302.56
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 66
# Episode ended after 219 steps
# Accumulated reward in this episode -218.0
# Mean reward so far -301.30
# Maximal reward so far -132.0
# -------------------------------------------------
# Episode 67
# Episode ended after 110 steps
# Accumulated reward in this episode -109.0
# Mean reward so far -298.47
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 68
# Episode ended after 165 steps
# Accumulated reward in this episode -164.0
# Mean reward so far -296.52
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 69
# Episode ended after 192 steps
# Accumulated reward in this episode -191.0
# Mean reward so far -295.01
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 70
# Episode ended after 128 steps
# Accumulated reward in this episode -127.0
# Mean reward so far -292.65
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 71
# Episode ended after 164 steps
# Accumulated reward in this episode -163.0
# Mean reward so far -290.85
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 72
# Episode ended after 240 steps
# Accumulated reward in this episode -239.0
# Mean reward so far -290.14
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 73
# Episode ended after 147 steps
# Accumulated reward in this episode -146.0
# Mean reward so far -288.19
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 74
# Episode ended after 139 steps
# Accumulated reward in this episode -138.0
# Mean reward so far -286.19
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 75
# Episode ended after 175 steps
# Accumulated reward in this episode -174.0
# Mean reward so far -284.71
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 76
# Episode ended after 155 steps
# Accumulated reward in this episode -154.0
# Mean reward so far -283.01
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 77
# Episode ended after 160 steps
# Accumulated reward in this episode -159.0
# Mean reward so far -281.42
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 78
# Episode ended after 326 steps
# Accumulated reward in this episode -325.0
# Mean reward so far -281.97
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 79
# Episode ended after 224 steps
# Accumulated reward in this episode -223.0
# Mean reward so far -281.24
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 80
# Episode ended after 179 steps
# Accumulated reward in this episode -178.0
# Mean reward so far -279.96
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 81
# Episode ended after 122 steps
# Accumulated reward in this episode -121.0
# Mean reward so far -278.02
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 82
# Episode ended after 147 steps
# Accumulated reward in this episode -146.0
# Mean reward so far -276.43
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 83
# Episode ended after 116 steps
# Accumulated reward in this episode -115.0
# Mean reward so far -274.51
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 84
# Episode ended after 112 steps
# Accumulated reward in this episode -111.0
# Mean reward so far -272.59
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 85
# Episode ended after 176 steps
# Accumulated reward in this episode -175.0
# Mean reward so far -271.45
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 86
# Episode ended after 149 steps
# Accumulated reward in this episode -148.0
# Mean reward so far -270.03
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 87
# Episode ended after 149 steps
# Accumulated reward in this episode -148.0
# Mean reward so far -268.65
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 88
# Episode ended after 122 steps
# Accumulated reward in this episode -121.0
# Mean reward so far -266.99
# Maximal reward so far -109.0
# -------------------------------------------------
# Episode 89
# Episode ended after 102 steps
# Accumulated reward in this episode -101.0
# Mean reward so far -265.14
# Maximal reward so far -101.0
# -------------------------------------------------
# Episode 90
# Episode ended after 122 steps
# Accumulated reward in this episode -121.0
# Mean reward so far -263.56
# Maximal reward so far -101.0
# -------------------------------------------------
# Episode 91
# Episode ended after 118 steps
# Accumulated reward in this episode -117.0
# Mean reward so far -261.97
# Maximal reward so far -101.0
# -------------------------------------------------
# Episode 92
# Episode ended after 166 steps
# Accumulated reward in this episode -165.0
# Mean reward so far -260.92
# Maximal reward so far -101.0
# -------------------------------------------------
# Episode 93
# Episode ended after 135 steps
# Accumulated reward in this episode -134.0
# Mean reward so far -259.57
# Maximal reward so far -101.0
# -------------------------------------------------
# Episode 94
# Episode ended after 159 steps
# Accumulated reward in this episode -158.0
# Mean reward so far -258.51
# Maximal reward so far -101.0
# -------------------------------------------------
# Episode 95
# Episode ended after 142 steps
# Accumulated reward in this episode -141.0
# Mean reward so far -257.28
# Maximal reward so far -101.0
# -------------------------------------------------
# Episode 96
# Episode ended after 124 steps
# Accumulated reward in this episode -123.0
# Mean reward so far -255.90
# Maximal reward so far -101.0
# -------------------------------------------------
# Episode 97
# Episode ended after 186 steps
# Accumulated reward in this episode -185.0
# Mean reward so far -255.17
# Maximal reward so far -101.0
# -------------------------------------------------
# Episode 98
# Episode ended after 148 steps
# Accumulated reward in this episode -147.0
# Mean reward so far -254.08
# Maximal reward so far -101.0
# -------------------------------------------------
# Episode 99
# Episode ended after 210 steps
# Accumulated reward in this episode -209.0
# Mean reward so far -253.63
# Maximal reward so far -101.0
# -------------------------------------------------
# Episode 100
# Episode ended after 87 steps
# Accumulated reward in this episode -86.0
# Mean reward so far -251.97
# Maximal reward so far -86.0
# -------------------------------------------------
# Episode 101
# Episode ended after 177 steps
# Accumulated reward in this episode -176.0
# Mean reward so far -251.23
# Maximal reward so far -86.0
# -------------------------------------------------
# Episode 102
# Episode ended after 127 steps
# Accumulated reward in this episode -126.0
# Mean reward so far -250.01
# Maximal reward so far -86.0
# -------------------------------------------------
# Episode 103
# Episode ended after 151 steps
# Accumulated reward in this episode -150.0
# Mean reward so far -249.05
# Maximal reward so far -86.0
# -------------------------------------------------
# Episode 104
# Episode ended after 181 steps
# Accumulated reward in this episode -180.0
# Mean reward so far -248.39
# Maximal reward so far -86.0
# -------------------------------------------------
# Episode 105
# Episode ended after 185 steps
# Accumulated reward in this episode -184.0
# Mean reward so far -247.78
# Maximal reward so far -86.0
# -------------------------------------------------
# Episode 106
# Episode ended after 191 steps
# Accumulated reward in this episode -190.0
# Mean reward so far -247.24
# Maximal reward so far -86.0
# -------------------------------------------------
# Episode 107
# Episode ended after 110 steps
# Accumulated reward in this episode -109.0
# Mean reward so far -245.96
# Maximal reward so far -86.0
# -------------------------------------------------
# Episode 108
# Episode ended after 223 steps
# Accumulated reward in this episode -222.0
# Mean reward so far -245.74
# Maximal reward so far -86.0
# -------------------------------------------------
# Episode 109
# Episode ended after 187 steps
# Accumulated reward in this episode -186.0
# Mean reward so far -245.20
# Maximal reward so far -86.0
# -------------------------------------------------
# Episode 110
# Episode ended after 201 steps
# Accumulated reward in this episode -200.0
# Mean reward so far -244.79
# Maximal reward so far -86.0
# -------------------------------------------------
# Episode 111
# Episode ended after 133 steps
# Accumulated reward in this episode -132.0
# Mean reward so far -243.79
# Maximal reward so far -86.0
# -------------------------------------------------
# Episode 112
# Episode ended after 130 steps
# Accumulated reward in this episode -129.0
# Mean reward so far -242.77
# Maximal reward so far -86.0
# -------------------------------------------------
# Episode 113
# Episode ended after 137 steps
# Accumulated reward in this episode -136.0
# Mean reward so far -241.83
# Maximal reward so far -86.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-fa0172b14670> in <module>()
#      15         while True:
#      16             # Propagate forward to compute action probability distribution
# ---> 17             apd = np.squeeze(sess.run(action_prob_dist, feed_dict = {input_ : obs.reshape((1,obs_dim[0]))}))
#      18             action = np.random.choice(np.arange(num_actions), p = apd)   # Sample an action based on the pdf
#      19             obs, reward, done, info = env.step(action)  # Take action and save observation, reward and done boolean
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Assess model performance

# %% [markdown]
# In order to get a sense of how good our model is, and to see if our agent improves in the training process, we can plot the mean rewards gained in one episode over the episode number. This value would grow as our agent becomes more skilled and gains more rewards in each episode.

# %%
plt.figure(figsize=(8,4))
plt.plot(mean_reward)
plt.xlabel("episode", fontsize=14)
plt.ylabel("mean reward", fontsize = 14)
plt.title("Mean episode rewards over episode number", fontsize = 16)
plt.grid()

# %% [markdown]
# ### Watch the agent play an episode

# %% [markdown]
# This is the fun part!
# Now we get to see how good our agent really is by watching it play an episode.

# %%
ep_reward = []
env = gym.make('Acrobot-v1')
env._max_episode_steps = 1000
# env = gym.wrappers.Monitor(env, "recording/LunarLander")
with tf.Session() as sess:
    saver.restore(sess, "models/Acrobot/model.ckpt") # load model
    obs = env.reset() # Reset env and save observation
    t = 0
    while True:
        env.render() # Render game
        # Use our model to create a probability distribution of actions based on observation
        apd = np.squeeze(sess.run(action_prob_dist, feed_dict={input_ : obs.reshape((1,obs_dim[0]))}))
        # Choose an action out of the PDF and take action
        action = np.random.choice(np.arange(num_actions), p = apd)
        obs, reward, done, info = env.step(action)
        ep_reward.append(reward)
        t = t+1
        if done:
            print("Game ended after {} steps".format(t+1))
            print("Total reward earned in this episode: {:0.2f}".format(sum(ep_reward)))
            break
env.close()

# %% [markdown]
# ### Test the trained model performance

# %%
num_ep = 10
ep_reward = []
batch_reward = []
env = gym.make('Acrobot-v1')
env._max_episode_steps = 1000
with tf.Session() as sess:
    saver.restore(sess, "models/LunarLander/model.ckpt") # load model
    for ep in range(num_ep):
        obs = env.reset() # Reset env and save observation
        t = 0
        while True:
            # Use our model to create a probability distribution of actions based on observation
            apd = np.squeeze(sess.run(action_prob_dist, feed_dict={input_ : obs.reshape((1,obs_dim[0]))}))
            # Choose an action out of the PDF and take action
            action = np.random.choice(np.arange(num_actions), p = apd)
            obs, reward, done, info = env.step(action)
            ep_reward.append(reward)
            t = t+1
            if done:
                print("-------------------------------------------")
                print("Game ended after {} steps".format(t+1))
                print("Total reward earned in this episode: {:0.2f}".format(sum(ep_reward)))
                batch_reward.append(sum(ep_reward))
                ep_reward = []
                break
print("===================================================")
print("Average reward in batch is {:0.2f}".format(np.mean(batch_reward)))
